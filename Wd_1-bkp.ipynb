# %% [markdown]
# Domain Adaptation using WDGRL architecture.
# Code gives the best and stable results in the method.

# %%
# %set_env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %set_env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=1

# %%
# %matplotlib notebook
from config import domainData
from config import num_classes as NUM_CLASSES
from torchvision import datasets, models, transforms
import yaml
import numpy as np
import matplotlib.pyplot as plt
import pickle as pkl
import logit
from random import shuffle
import math
import utils

# %%
import torch
import torch.nn as nn
import torch.autograd as autograd
import torch.optim as optim
from torch.autograd import Variable

# %%
# src_pkl = domainData['amazon_resnet50']
# tar_pkl = domainData['webcam_resnet50']
src_pkl = "./amazon_alexnet_4096.pkl"
tar_pkl = "./webcam_alexnet_4096.pkl"
# src_pkl = './amazon_4096.yml'
# tar_pkl = './webcam_4096.yml'

# %%
with open(src_pkl, 'rb') as f:
    src_data = pkl.load(f)
with open(tar_pkl, 'rb') as f:
    tar_data = pkl.load(f)

# with open(src_pkl, 'r') as f:
#     source = yaml.load(f)
# with open(tar_pkl, 'r') as f:
#     target = yaml.load(f)

# %% [markdown]
# def batch_generator(data, batch_size, shuffle=True):
#     len_data = len(data['features'])
#     def shuffle_data():
#         nonlocal len_data
#         idx = list(range(len_data))
#         idx = np.random.permutation(idx)
#         t_features = [data['features'][i] for i in idx]
#         t_labels = [data['labels'][i] for i in idx]
#         data['features'] = t_features
#         data['labels'] = t_labels
#     if shuffle:
#         shuffle_data()
#     batch_count = 0
#     while True:
#         if batch_count * batch_size + batch_size >= len_data:
#             batch_count = 0
#             if shuffle:
#                 shuffle_data()
#         start = (int) (batch_count * batch_size)
#         end = (int) (start + batch_size)
#         batch_count += 1
#         yield torch.stack(data['features'][start:end]), np.vstack(src_data['labels'][start:end])

# %%
wd_param = 0.1
gp_param = 10
lr_wd_D = 1e-3
D_train_num = 10

l2_param = 1e-5
lr = 1e-4
batch_size = 64
num_steps = 3200
num_class = 31
n_input = 4096
n_hidden = [2048, 1024, 512, 256]
lr_sch = None

use_gpu = True

# %%
xs, ys = src_data['features'], src_data['labels']
xt, yt = tar_data['features'], tar_data['labels']
ys = ys.squeeze()
yt = yt.squeeze()
# xs = source['train']
# ys = source['train_labels']
# xt = target['train']
# yt = target['train_labels']

# %%
class _Generator(nn.Module):
    def __init__(self, act=nn.ReLU(inplace=True)):
        super(_Generator, self).__init__()
        self.h1 = nn.Sequential(nn.Linear(n_input, n_hidden[0]), act,
                                nn.Linear(n_hidden[0], n_hidden[1]), act,
                                nn.Linear(n_hidden[1], n_hidden[2]), act,
                                nn.Linear(n_hidden[2], n_hidden[3]), act
                                )
        utils.weight_init(self.h1)

    def forward(self, x):
        out = self.h1(x)
        return out

class _Classifier(nn.Module):
    """
    Using nn.CrossEntropyLoss() for tf.nn.softmax_cross_entropy_with_logits()
    There is difference in target labels. This loss requires target labels
    in range [0,C-1] instead of one-hot-encoding, as required in tensorflow.
    Also, CrossEntropyLoss() uses LogSoftmax instead of normal Softmax.
    """
    def __init__(self, act=nn.ReLU(inplace=True)):
        super(_Classifier, self).__init__()
        self.h = nn.Sequential(nn.Linear(n_hidden[-1], 128), act,
                               nn.Linear(128, 64), act,
                               nn.Linear(64, num_class))
        utils.weight_init(self.h)

    def forward(self, x):
        out = self.h(x)
        return out

class _Critic(nn.Module):
    def __init__(self, act=nn.ReLU(inplace=True)):
        super(_Critic, self).__init__()
        self.h1 = nn.Sequential(nn.Linear(n_hidden[-1], 128), act,
                               nn.Linear(128, 64), act,
                               nn.Linear(64, 1))
        utils.weight_init(self.h1)

    def forward(self, x):
        out = self.h1(x)
        return out

class Model(object):
    def __init__(self):
        self.cr = _Critic()
        self.gen = _Generator()
        self.cls = _Classifier()

# %%
model = Model()
model.cr = model.cr.cuda() if use_gpu else model.cr
model.gen = model.gen.cuda() if use_gpu else model.gen
model.cls = model.cls.cuda() if use_gpu else model.cls

# %%
# cls_criterion = nn.CrossEntropyLoss()
cls_criterion = utils.softmax_cross_entropy_with_logits(num_class)
l2_reg = utils.L2_Loss()
softmax_ = nn.Softmax(dim=1)

params_wd = [
{'params': model.cr.parameters(), 'lr': lr_wd_D}
]
# wd_d_op = optim.SGD(params_wd, momentum=0.9)
wd_d_op = optim.Adam(params_wd)

params = [
{'params': model.gen.parameters(), 'lr': lr},
{'params': model.cls.parameters(), 'lr': lr}
]
# train_op = optim.SGD(params, momentum=0.9)
train_op = optim.Adam(params)
lr_sch = optim.lr_scheduler.ExponentialLR(train_op, 0.1)

# %% [markdown]
# S_batches = batch_generator(src_data, batch_size)
# xs_batch, ys_batch = next(S_batches)

# %%
def test(i, acc):
    XS = torch.from_numpy(xs).float()
    XS = XS.cuda() if use_gpu else XS
    y_true = torch.from_numpy(ys).long()
    y_true = y_true.cuda() if use_gpu else y_true
    
    XS = Variable(XS, volatile=True)
    y_true = Variable(y_true, requires_grad=False)
    
    h2 = model.gen(XS)
    logits = model.cls(h2)
    clf_loss = cls_criterion(logits, y_true)
    logits = softmax_(logits)
    _, pred_idx = torch.max(logits, 1)
    clf_acc = torch.eq(pred_idx, y_true).float().mean()
#     clf_acc = torch.sum(pred_idx == y_true) / y_true.size(0)
    print('step: ', i)
    print('source classifier loss: %f, source accuracy: %f' % (clf_loss, clf_acc))
    acc['src'].append(clf_acc.cpu().data.numpy())

    XS = torch.from_numpy(xt).float()
    XS = XS.cuda() if use_gpu else XS
    y_true = torch.from_numpy(yt).long()
    y_true = y_true.cuda() if use_gpu else y_true
    
    XS = Variable(XS, volatile=True)
    y_true = Variable(y_true, requires_grad=False)
    
    h2 = model.gen(XS)
    logits = model.cls(h2)
    clf_loss = cls_criterion(logits, y_true)
    logits = softmax_(logits)
    _, pred_idx = torch.max(logits, 1)
    clf_acc = torch.eq(pred_idx, y_true).float().mean()
#     clf_acc = torch.sum(pred_idx == y_true) / y_true.size(0)
    print('target classifier loss: %f, target accuracy: %f' % (clf_loss, clf_acc))
#     ax.plot(clf_acc)
    acc['tar'].append(clf_acc.cpu().data.numpy())

# %%
acc = { 'src': [], 'tar': [] }

def train():

    # put all network in training mode
    model.gen.train()
    model.cr.train()
    model.cls.train()

    S_batches = utils.batch_generator([xs, ys], batch_size / 2)
    T_batches = utils.batch_generator([xt, yt], batch_size / 2)

    for i in range(num_steps):
        xs_batch, ys_batch = next(S_batches)
        xt_batch, yt_batch = next(T_batches)
        xb = np.vstack([xs_batch, xt_batch])
        # yb = np.hstack([ys_batch, yt_batch])

        for _ in range(D_train_num):
            wd_d_op.zero_grad()
            XB = torch.from_numpy(xb).float()
            if use_gpu:
                XB = XB.cuda()
            XB = Variable(XB)
            h2 = model.gen(XB)
            h2_s = h2[:batch_size // 2]
            h2_t = h2[batch_size // 2:]

            alpha = torch.Tensor(h2_s.size()).uniform_(0.1,0.9)
            if use_gpu:
                alpha = alpha.cuda()
            difference = h2_s.data - h2_t.data
            interpolates = h2_s.data + (alpha * difference)
#             h2_whole = interpolates

            h2_whole = torch.cat([h2.data, interpolates])

            if use_gpu:
                h2_whole = h2_whole.cuda()
            h2_whole = Variable(h2_whole, requires_grad=True)
            critic_out1 = model.cr(h2)
            critic_out = model.cr(h2_whole)

            critic_s = critic_out1[:batch_size // 2]
#             critic_t = critic_out1[batch_size // 2:]
            critic_t = critic_out[batch_size // 2:batch_size]
            
            wd_loss = torch.sigmoid(critic_t) ** 2 + (1. - torch.sigmoid(critic_s)) ** 2
            wd_loss = wd_loss.mean()

#             wd_loss = critic_s.mean() - critic_t.mean()


            ones = torch.ones(critic_out.size())
            if use_gpu:
                ones = ones.cuda()

            grads = autograd.grad(critic_out, h2_whole, grad_outputs=ones,
                retain_graph=True, create_graph=True, only_inputs=True)[0]

#             slopes = torch.sqrt(torch.sum(grads ** 2, dim=1))
#             gradient_penalty = ((slopes - 1.) ** 2).mean()
            gradient_penalty = ((grads.norm(2, dim=1) - 1) ** 2).mean() 

#             grads = grads.view(grads.size(0), -1)
#             gradient_penalty = ((grads.norm(2, dim=1) - 1.) ** 2).mean()l

            wd_loss_t = wd_loss + gp_param * gradient_penalty
            wd_loss_t.backward()
            wd_d_op.step()

        train_op.zero_grad()        
        XB = torch.from_numpy(xb).float()
        ys_batch = torch.from_numpy(ys_batch).long()
        if use_gpu:
            XB = XB.cuda()
            ys_batch = ys_batch.cuda()
        XB = Variable(XB)
        ys_batch = Variable(ys_batch, requires_grad=False)
        h2 = model.gen(XB)
        h2_s = h2[:batch_size // 2]
        h2_t = h2[batch_size // 2:]

        alpha = torch.Tensor(h2_s.size()).uniform_(0.1,0.9)
        if use_gpu:
            alpha = alpha.cuda()
        difference = h2_s.data - h2_t.data
        interpolates = h2_s.data + (alpha * difference)

        h2_whole = torch.cat([h2.data, interpolates])
        h2_whole = Variable(h2_whole, requires_grad=True)
        
        critic_out = model.cr(h2_whole)
#         critic_out = model.cr(h2)
    
        critic_s = critic_out[:batch_size // 2]
        critic_t = critic_out[batch_size // 2:batch_size]
#         critic_t = critic_out[batch_size // 2:]

        wd_loss = critic_s - critic_t
        wd_loss = wd_loss.mean()

        pred_logit = model.cls(h2_s)
        clf_loss = cls_criterion(pred_logit, ys_batch)

        # https://discuss.pytorch.org/t/simple-l2-regularization/139/2
        # https://discuss.pytorch.org/t/add-custom-regularizer-to-loss/4831/2
        l2_loss = None
        for name, param in model.gen.named_parameters():
            if 'weight' in name:
                if l2_loss is None:
                    l2_loss = l2_reg(param) * l2_param
                else:
                    l2_loss += l2_reg(param) * l2_param
        for name, param in model.cr.named_parameters():
            if 'weight' in name:	
                l2_loss += l2_reg(param) * l2_param
                
        P = i / num_steps
#         utils.adjust_learning_rate(train_op, P)
        lmbd = 2. / (1. + math.exp(-10 * P)) - 1.
#         print("new wd_param:", lmbd)
        total_loss = clf_loss + l2_loss + (1. - lmbd) * wd_loss
        # total_loss = clf_loss + wd_param * wd_loss
        total_loss.backward()
        train_op.step()
        
        if i % 500 == 0 and lr_sch is not None:
            lr_sch.step()

        if i % 10 == 0:
            print(lmbd)
            test(i, acc)

# %%
# %time train()
# Out:
# 0.0
# step:  0
# source classifier loss: 5.994503, source accuracy: 0.028044
# target classifier loss: 5.165255, target accuracy: 0.031447
# 0.015623728558408878
# step:  10
# source classifier loss: 3.272977, source accuracy: 0.106141
# target classifier loss: 3.407083, target accuracy: 0.061635
# 0.031239831446031152
# step:  20
# source classifier loss: 2.994215, source accuracy: 0.202343
# target classifier loss: 3.101991, target accuracy: 0.164780
# 0.04684069787264811
# step:  30
# source classifier loss: 2.706663, source accuracy: 0.246716
# target classifier loss: 3.136779, target accuracy: 0.130818
# 0.06241874674751258
# step:  40
# source classifier loss: 2.507775, source accuracy: 0.326944
# target classifier loss: 3.045222, target accuracy: 0.161006
# 0.07796644137536823
# step:  50
# source classifier loss: 2.370466, source accuracy: 0.363862
# target classifier loss: 2.830317, target accuracy: 0.225157
# 0.09347630396922768
# step:  60
# source classifier loss: 2.149495, source accuracy: 0.392261
# target classifier loss: 2.804698, target accuracy: 0.211321
# 0.10894092992085458
# step:  70
# source classifier loss: 2.003375, source accuracy: 0.463969
# target classifier loss: 2.733778, target accuracy: 0.259120
# 0.12435300177159614
# step:  80
# source classifier loss: 1.942373, source accuracy: 0.477103
# target classifier loss: 2.680477, target accuracy: 0.251572
# 0.13970530282831417
# step:  90
# source classifier loss: 1.861024, source accuracy: 0.503727
# target classifier loss: 2.498355, target accuracy: 0.334591
# 0.1549907303716236
# step:  100
# source classifier loss: 1.967892, source accuracy: 0.480653
# target classifier loss: 2.704458, target accuracy: 0.277987
# 0.17020230840646233
# step:  110
# source classifier loss: 1.921516, source accuracy: 0.450479
# target classifier loss: 2.661548, target accuracy: 0.235220
# 0.18533319990813935
# step:  120
# source classifier loss: 1.769111, source accuracy: 0.510117
# target classifier loss: 2.442281, target accuracy: 0.342138
# 0.20037671852040995
# step:  130
# source classifier loss: 1.621245, source accuracy: 0.575080
# target classifier loss: 2.462928, target accuracy: 0.306918
# 0.2153263396657834
# step:  140
# source classifier loss: 1.653525, source accuracy: 0.547391
# target classifier loss: 2.381778, target accuracy: 0.324528
# 0.23017571103213297
# step:  150
# source classifier loss: 1.866564, source accuracy: 0.491303
# target classifier loss: 2.455101, target accuracy: 0.329560
# 0.2449186624037092
# step:  160
# source classifier loss: 1.671131, source accuracy: 0.539936
# target classifier loss: 2.423788, target accuracy: 0.347170
# 0.25954921480882676
# step:  170
# source classifier loss: 1.476791, source accuracy: 0.607739
# target classifier loss: 2.381482, target accuracy: 0.368553
# 0.27406158896076627
# step:  180
# source classifier loss: 1.393402, source accuracy: 0.650692
# target classifier loss: 2.341297, target accuracy: 0.354717
# 0.2884502129727393
# step:  190
# source classifier loss: 1.337718, source accuracy: 0.643237
# target classifier loss: 2.258051, target accuracy: 0.389937
# 0.3027097293321084
# step:  200
# source classifier loss: 1.345300, source accuracy: 0.640398
# target classifier loss: 2.402575, target accuracy: 0.355975
# 0.31683500112336604
# step:  210
# source classifier loss: 1.321118, source accuracy: 0.633298
# target classifier loss: 2.171713, target accuracy: 0.421384
# 0.33082111749362797
# step:  220
# source classifier loss: 1.501934, source accuracy: 0.601704
# target classifier loss: 2.568476, target accuracy: 0.310692
# 0.34466339835857207
# step:  230
# source classifier loss: 1.262186, source accuracy: 0.657792
# target classifier loss: 2.363558, target accuracy: 0.388679
# 0.35835739835078595
# step:  240
# source classifier loss: 1.342763, source accuracy: 0.641463
# target classifier loss: 2.556378, target accuracy: 0.349686
# 0.371898910016385
# step:  250
# source classifier loss: 1.202137, source accuracy: 0.675186
# target classifier loss: 2.130328, target accuracy: 0.391195
# 0.38528396626947226
# step:  260
# source classifier loss: 1.211274, source accuracy: 0.692226
# target classifier loss: 2.230608, target accuracy: 0.377358
# 0.3985088421175169
# step:  270
# source classifier loss: 1.105119, source accuracy: 0.710685
# target classifier loss: 2.169142, target accuracy: 0.403774
# 0.4115700556740225
# step:  280
# source classifier loss: 1.054854, source accuracy: 0.722755
# target classifier loss: 2.090226, target accuracy: 0.428931
# 0.4244643684778939
# step:  290
# source classifier loss: 1.004814, source accuracy: 0.728435
# target classifier loss: 2.117246, target accuracy: 0.407547
# 0.4371887851417122
# step:  300
# source classifier loss: 1.144060, source accuracy: 0.692226
# target classifier loss: 2.267998, target accuracy: 0.389937
# 0.4497405523536495
# step:  310
# source classifier loss: 1.142440, source accuracy: 0.695066
# target classifier loss: 2.199888, target accuracy: 0.396226
# 0.4621171572600098
# step:  320
# source classifier loss: 1.089272, source accuracy: 0.712105
# target classifier loss: 2.326688, target accuracy: 0.369811
# 0.4743163252573668
# step:  330
# source classifier loss: 1.288900, source accuracy: 0.658147
# target classifier loss: 2.572762, target accuracy: 0.364780
# 0.4863360172249622
# step:  340
# source classifier loss: 1.104877, source accuracy: 0.704295
# target classifier loss: 2.092688, target accuracy: 0.392453
# 0.49817442622945496
# step:  350
# source classifier loss: 0.966853, source accuracy: 0.737664
# target classifier loss: 2.095212, target accuracy: 0.403774
# 0.5098299737352565
# step:  360
# source classifier loss: 1.010799, source accuracy: 0.731629
# target classifier loss: 2.222646, target accuracy: 0.408805
# 0.5213013053545767
# step:  370
# source classifier loss: 0.988517, source accuracy: 0.730209
# target classifier loss: 2.209720, target accuracy: 0.403774
# 0.5325872861719194
# step:  380
# source classifier loss: 0.988747, source accuracy: 0.728079
# target classifier loss: 2.126667, target accuracy: 0.415094
# 0.5436869956781494
# step:  390
# source classifier loss: 1.047957, source accuracy: 0.703585
# target classifier loss: 2.321187, target accuracy: 0.401258
# 0.5545997223493822
# step:  400
# source classifier loss: 0.854485, source accuracy: 0.771743
# target classifier loss: 1.994219, target accuracy: 0.446541
# 0.5653249579058752
# step:  410
# source classifier loss: 0.841837, source accuracy: 0.776003
# target classifier loss: 2.137624, target accuracy: 0.396226
# 0.5758623912857894
# step:  420
# source classifier loss: 0.847151, source accuracy: 0.779908
# target classifier loss: 2.151638, target accuracy: 0.423899
# 0.5862119023682237
# step:  430
# source classifier loss: 0.939383, source accuracy: 0.741924
# target classifier loss: 2.121387, target accuracy: 0.422642
# 0.5963735554792424
# step:  440
# source classifier loss: 0.823352, source accuracy: 0.780973
# target classifier loss: 2.196980, target accuracy: 0.415094
# 0.6063475927138031
# step:  450
# source classifier loss: 0.774686, source accuracy: 0.788072
# target classifier loss: 2.144227, target accuracy: 0.413836
# 0.6161344271055265
# step:  460
# source classifier loss: 0.836334, source accuracy: 0.769968
# target classifier loss: 2.231903, target accuracy: 0.418868
# 0.625734635675147
# step:  470
# source classifier loss: 0.741877, source accuracy: 0.803337
# target classifier loss: 2.108700, target accuracy: 0.435220
# 0.6351489523872873
# step:  480
# source classifier loss: 0.809007, source accuracy: 0.777068
# target classifier loss: 2.231885, target accuracy: 0.381132
# 0.6443782610439006
# step:  490
# source classifier loss: 0.750799, source accuracy: 0.796237
# target classifier loss: 2.232898, target accuracy: 0.440252
# 0.6534235881413468
# step:  500
# source classifier loss: 0.756807, source accuracy: 0.794817
# target classifier loss: 2.162646, target accuracy: 0.423899
# 0.6622860957166337
# step:  510
# source classifier loss: 0.676218, source accuracy: 0.822151
# target classifier loss: 2.083911, target accuracy: 0.433962
# 0.6709670742068738
# step:  520
# source classifier loss: 0.609828, source accuracy: 0.846290
# target classifier loss: 2.055169, target accuracy: 0.466667
# 0.6794679353444786
# step:  530
# source classifier loss: 0.589316, source accuracy: 0.854455
# target classifier loss: 2.057812, target accuracy: 0.465409
# 0.6877902051090852
# step:  540
# source classifier loss: 0.568354, source accuracy: 0.860135
# target classifier loss: 2.035918, target accuracy: 0.472956
# 0.6959355167556514
# step:  550
# source classifier loss: 0.558158, source accuracy: 0.864750
# target classifier loss: 2.023372, target accuracy: 0.459119
# 0.7039056039366212
# step:  560
# source classifier loss: 0.544307, source accuracy: 0.865105
# target classifier loss: 2.018423, target accuracy: 0.456604
# 0.7117022939345188
# step:  570
# source classifier loss: 0.542621, source accuracy: 0.864395
# target classifier loss: 2.045375, target accuracy: 0.470440
# 0.7193275010198334
# step:  580
# source classifier loss: 0.534425, source accuracy: 0.869365
# target classifier loss: 2.054361, target accuracy: 0.464151
# 0.7267832199475612
# step:  590
# source classifier loss: 0.522264, source accuracy: 0.872204
# 0.8568176011108952
# step:  820
# source classifier loss: 0.434053, source accuracy: 0.897764
# target classifier loss: 2.033334, target accuracy: 0.483019
# 0.8609165109883439
# step:  830
# source classifier loss: 0.442914, source accuracy: 0.894569
# target classifier loss: 1.985348, target accuracy: 0.485535
# 0.8649066177207418
# step:  840
# source classifier loss: 0.434849, source accuracy: 0.899539
# target classifier loss: 1.990155, target accuracy: 0.470440
# 0.8687903250818612
# step:  850
# source classifier loss: 0.435063, source accuracy: 0.893859
# target classifier loss: 2.011390, target accuracy: 0.464151
# 0.8725700114960693
# step:  860
# source classifier loss: 0.421648, source accuracy: 0.898119
# target classifier loss: 2.003290, target accuracy: 0.467925
# 0.8762480285527146
# step:  870
# source classifier loss: 0.421628, source accuracy: 0.900958
# target classifier loss: 2.060944, target accuracy: 0.461635
# 0.8798266996519848
# step:  880
# source classifier loss: 0.422617, source accuracy: 0.898119
# target classifier loss: 2.095850, target accuracy: 0.456604
# 0.883308318776638
# step:  890
# source classifier loss: 0.416091, source accuracy: 0.902733
# target classifier loss: 2.070330, target accuracy: 0.466667
# 0.8866951493840523
# step:  900
# source classifier loss: 0.420614, source accuracy: 0.900603
# target classifier loss: 2.109102, target accuracy: 0.464151
# 0.8899894234130918
# step:  910
# source classifier loss: 0.409130, source accuracy: 0.903088
# target classifier loss: 2.056297, target accuracy: 0.461635
# 0.8931933404003514
# step:  920
# source classifier loss: 0.410329, source accuracy: 0.904153
# target classifier loss: 2.028325, target accuracy: 0.461635
# 0.8963090667004401
# step:  930
# source classifier loss: 0.405427, source accuracy: 0.904153
# target classifier loss: 2.029536, target accuracy: 0.464151
# 0.8993387348050463
# step:  940
# source classifier loss: 0.401195, source accuracy: 0.906993
# target classifier loss: 2.020049, target accuracy: 0.476730
# 0.9022844427556502
# step:  950
# source classifier loss: 0.399741, source accuracy: 0.904863
# target classifier loss: 2.054200, target accuracy: 0.476730
# 0.9051482536448667
# step:  960
# source classifier loss: 0.402025, source accuracy: 0.907348
# target classifier loss: 2.123553, target accuracy: 0.467925
# 0.9079321952015194
# step:  970
# source classifier loss: 0.392074, source accuracy: 0.910543
# target classifier loss: 2.029752, target accuracy: 0.477987
# 0.9106382594546996
# step:  980
# source classifier loss: 0.386932, source accuracy: 0.913028
# target classifier loss: 1.995028, target accuracy: 0.479245
# 0.9132684024721864
# step:  990
# source classifier loss: 0.386396, source accuracy: 0.912673
# target classifier loss: 2.009056, target accuracy: 0.469182
# 0.9158245441687622
# step:  1000
# source classifier loss: 0.385116, source accuracy: 0.910188
# target classifier loss: 2.028084, target accuracy: 0.475472
# 0.9183085681801013
# step:  1010
# source classifier loss: 0.383760, source accuracy: 0.909833
# target classifier loss: 2.026132, target accuracy: 0.474214
# 0.92072232179806
# step:  1020
# source classifier loss: 0.381584, source accuracy: 0.911963
# target classifier loss: 2.026636, target accuracy: 0.471698
# 0.9230676159633513
# step:  1030
# source classifier loss: 0.379460, source accuracy: 0.913383
# target classifier loss: 2.032164, target accuracy: 0.469182
# 0.9253462253117413
# step:  1040
# source classifier loss: 0.377559, source accuracy: 0.913738
# target classifier loss: 2.037974, target accuracy: 0.470440
# 0.9275598882700506
# step:  1050
# source classifier loss: 0.376362, source accuracy: 0.913028
# target classifier loss: 2.040821, target accuracy: 0.466667
# 0.9297103071984134
# step:  1060
# source classifier loss: 0.375649, source accuracy: 0.912673
# target classifier loss: 2.042071, target accuracy: 0.466667
# 0.9317991485753769
# step:  1070
# source classifier loss: 0.375020, source accuracy: 0.913738
# target classifier loss: 2.037543, target accuracy: 0.467925
# 0.9338280432225916
# step:  1080
# source classifier loss: 0.374481, source accuracy: 0.914448
# target classifier loss: 2.034501, target accuracy: 0.467925
# 0.9357985865659837
# step:  1090
# source classifier loss: 0.373972, source accuracy: 0.914803
# target classifier loss: 2.031689, target accuracy: 0.467925
# 0.9377123389304431
# step:  1100
# source classifier loss: 0.373566, source accuracy: 0.914448
# target classifier loss: 2.028462, target accuracy: 0.467925
# 0.9395708258652122
# step:  1110
# source classifier loss: 0.373249, source accuracy: 0.915513
# target classifier loss: 2.028089, target accuracy: 0.470440
# 0.9413755384972873
# step:  1120
# source classifier loss: 0.372658, source accuracy: 0.914803
# target classifier loss: 2.031529, target accuracy: 0.470440
# 0.9431279339102947
# step:  1130
# source classifier loss: 0.372125, source accuracy: 0.916223
# target classifier loss: 2.040065, target accuracy: 0.467925
# 0.9448294355464197
# step:  1140
# source classifier loss: 0.371569, source accuracy: 0.915868
# target classifier loss: 2.050757, target accuracy: 0.465409
# 0.9464814336291136
# step:  1150
# source classifier loss: 0.371253, source accuracy: 0.915868
# target classifier loss: 2.054266, target accuracy: 0.465409
# 0.9480852856044062
# step:  1160
# source classifier loss: 0.371225, source accuracy: 0.915868
# target classifier loss: 2.056814, target accuracy: 0.466667
# 0.9496423165987962
# step:  1170
# source classifier loss: 0.370896, source accuracy: 0.916223
# target classifier loss: 2.055632, target accuracy: 0.467925
# 0.9511538198917857
# step:  1180
# source classifier loss: 0.370506, source accuracy: 0.917288
# target classifier loss: 2.051776, target accuracy: 0.462893
# 0.9526210574012512
# step:  1190
# source classifier loss: 0.370193, source accuracy: 0.916933
# target classifier loss: 2.052542, target accuracy: 0.464151
# 0.9540452601799487
# step:  1200
# source classifier loss: 0.370002, source accuracy: 0.916933
# target classifier loss: 2.054741, target accuracy: 0.464151
# 0.9554276289215491
# step:  1210
# source classifier loss: 0.369386, source accuracy: 0.916578
# target classifier loss: 2.052395, target accuracy: 0.462893
# 0.9567693344747048
# step:  1220
# source classifier loss: 0.368720, source accuracy: 0.915868
# target classifier loss: 2.050771, target accuracy: 0.462893
# 0.9580715183637447
# step:  1230
# source classifier loss: 0.368222, source accuracy: 0.916578
# target classifier loss: 2.049001, target accuracy: 0.465409
# 0.9593352933146824
# step:  1240
# source classifier loss: 0.368076, source accuracy: 0.915513
# target classifier loss: 2.048953, target accuracy: 0.465409
# 0.9605617437853069
# step:  1250
# source classifier loss: 0.368199, source accuracy: 0.916933
# target classifier loss: 2.047065, target accuracy: 0.464151
# 0.9617519264982224
# step:  1260
# source classifier loss: 0.368042, source accuracy: 0.916578
# target classifier loss: 2.047518, target accuracy: 0.464151
# 0.9629068709757655
# step:  1270
# source classifier loss: 0.367451, source accuracy: 0.916578
# target classifier loss: 2.052289, target accuracy: 0.464151
# 0.9640275800758169
# step:  1280
# source classifier loss: 0.366833, source accuracy: 0.917643
# target classifier loss: 2.053546, target accuracy: 0.465409
# 0.9651150305275895
# step:  1290
# source classifier loss: 0.366334, source accuracy: 0.917643
# target classifier loss: 2.049453, target accuracy: 0.464151
# 0.9661701734665469
# step:  1300
# source classifier loss: 0.366064, source accuracy: 0.916933
# target classifier loss: 2.045768, target accuracy: 0.464151
# 0.9671939349676739
# step:  1310
# source classifier loss: 0.365768, source accuracy: 0.917998
# target classifier loss: 2.043847, target accuracy: 0.466667
# 0.9681872165763705
# step:  1320
# source classifier loss: 0.365357, source accuracy: 0.918708
# target classifier loss: 2.051004, target accuracy: 0.466667
# 0.9691508958363175
# step:  1330
# source classifier loss: 0.365413, source accuracy: 0.919773
# target classifier loss: 2.057958, target accuracy: 0.462893
# 0.9700858268137
# step:  1340
# source classifier loss: 0.365060, source accuracy: 0.920128
# target classifier loss: 2.058478, target accuracy: 0.464151
# 0.9709928406172359
# step:  1350
# source classifier loss: 0.364519, source accuracy: 0.918708
# target classifier loss: 2.057489, target accuracy: 0.464151
# 0.9718727459135088
# step:  1360
# source classifier loss: 0.364266, source accuracy: 0.919418
# target classifier loss: 2.060124, target accuracy: 0.462893
# 0.9727263294371402
# step:  1370
# source classifier loss: 0.364099, source accuracy: 0.919418
# target classifier loss: 2.054633, target accuracy: 0.465409
# 0.9735543564953897
# step:  1380
# source classifier loss: 0.363572, source accuracy: 0.919773
# target classifier loss: 2.050778, target accuracy: 0.464151
# 0.9743575714668116
# step:  1390
# source classifier loss: 0.363141, source accuracy: 0.920128
# target classifier loss: 2.054546, target accuracy: 0.464151
# 0.9751366982936283
# step:  1400
# source classifier loss: 0.362770, source accuracy: 0.920128
# target classifier loss: 2.056280, target accuracy: 0.462893
# 0.9758924409675269
# step:  1410
# source classifier loss: 0.362399, source accuracy: 0.919063
# target classifier loss: 2.056961, target accuracy: 0.464151
# 0.9766254840086113
# step:  1420
# source classifier loss: 0.362170, source accuracy: 0.919773
# target classifier loss: 2.059407, target accuracy: 0.461635
# 0.977336492937277
# step:  1430
# source classifier loss: 0.361988, source accuracy: 0.919418
# target classifier loss: 2.055208, target accuracy: 0.462893
# 0.9780261147388136
# step:  1440
# source classifier loss: 0.361724, source accuracy: 0.919773
# target classifier loss: 2.054412, target accuracy: 0.462893
# 0.9786949783205476
# step:  1450
# source classifier loss: 0.361605, source accuracy: 0.918708
# target classifier loss: 2.053885, target accuracy: 0.464151
# 0.9793436949613898
# step:  1460
# source classifier loss: 0.361178, source accuracy: 0.919063
# target classifier loss: 2.055303, target accuracy: 0.464151
# 0.9799728587536536
# step:  1470
# source classifier loss: 0.360589, source accuracy: 0.920483
# target classifier loss: 2.055674, target accuracy: 0.462893
# 0.9975103133958232
# step:  2140
# source classifier loss: 0.357881, source accuracy: 0.921193
# target classifier loss: 2.058357, target accuracy: 0.462893
# 0.9975868205755074
# step:  2150
# source classifier loss: 0.357877, source accuracy: 0.921193
# target classifier loss: 2.058290, target accuracy: 0.462893
# 0.997660979469889
# step:  2160
# source classifier loss: 0.357874, source accuracy: 0.921193
# target classifier loss: 2.058207, target accuracy: 0.462893
# 0.9977328619898251
# step:  2170
# source classifier loss: 0.357870, source accuracy: 0.921193
# target classifier loss: 2.058156, target accuracy: 0.462893
# 0.9978025378541506
# step:  2180
# source classifier loss: 0.357867, source accuracy: 0.921193
# target classifier loss: 2.058165, target accuracy: 0.462893
# 0.9978700746558882
# step:  2190
# source classifier loss: 0.357863, source accuracy: 0.921193
# target classifier loss: 2.058228, target accuracy: 0.462893
# 0.9979355379264905
# step:  2200
# source classifier loss: 0.357859, source accuracy: 0.921548
# target classifier loss: 2.058301, target accuracy: 0.462893
# 0.9979989911981799
# step:  2210
# source classifier loss: 0.357856, source accuracy: 0.921548
# target classifier loss: 2.058318, target accuracy: 0.462893
# 0.9980604960644348
# step:  2220
# source classifier loss: 0.357852, source accuracy: 0.921548
# target classifier loss: 2.058328, target accuracy: 0.462893
# 0.9981201122386745
# step:  2230
# source classifier loss: 0.357849, source accuracy: 0.921548
# target classifier loss: 2.058319, target accuracy: 0.462893
# 0.9981778976111988
# step:  2240
# source classifier loss: 0.357845, source accuracy: 0.921193
# target classifier loss: 2.058265, target accuracy: 0.462893
# 0.9982339083044309
# step:  2250
# source classifier loss: 0.357842, source accuracy: 0.921193
# target classifier loss: 2.058214, target accuracy: 0.462893
# 0.9982881987265098
# step:  2260
# source classifier loss: 0.357838, source accuracy: 0.921193
# target classifier loss: 2.058251, target accuracy: 0.462893
# 0.9983408216232819
# step:  2270
# source classifier loss: 0.357834, source accuracy: 0.921548
# target classifier loss: 2.058283, target accuracy: 0.462893
# 0.9983918281287416
# step:  2280
# source classifier loss: 0.357831, source accuracy: 0.921548
# target classifier loss: 2.058299, target accuracy: 0.462893
# 0.9984412678139583
# step:  2290
# source classifier loss: 0.357828, source accuracy: 0.921548
# target classifier loss: 2.058325, target accuracy: 0.462893
# 0.9984891887345411
# step:  2300
# source classifier loss: 0.357825, source accuracy: 0.921548
# target classifier loss: 2.058341, target accuracy: 0.462893
# 0.9985356374766783
# step:  2310
# source classifier loss: 0.357821, source accuracy: 0.921548
# target classifier loss: 2.058353, target accuracy: 0.462893
# 0.998580659201799
# step:  2320
# source classifier loss: 0.357817, source accuracy: 0.921548
# target classifier loss: 2.058351, target accuracy: 0.462893
# 0.9986242976898896
# step:  2330
# source classifier loss: 0.357814, source accuracy: 0.921548
# target classifier loss: 2.058376, target accuracy: 0.462893
# 0.998666595381513
# step:  2340
# source classifier loss: 0.357810, source accuracy: 0.921548
# target classifier loss: 2.058346, target accuracy: 0.462893
# 0.9987075934185607
# step:  2350
# source classifier loss: 0.357806, source accuracy: 0.921548
# target classifier loss: 2.058351, target accuracy: 0.462893
# 0.9987473316837809
# step:  2360
# source classifier loss: 0.357802, source accuracy: 0.921548
# target classifier loss: 2.058362, target accuracy: 0.462893
# 0.998785848839117
# step:  2370
# source classifier loss: 0.357799, source accuracy: 0.921548
# target classifier loss: 2.058327, target accuracy: 0.462893
# 0.9988231823628861
# step:  2380
# source classifier loss: 0.357795, source accuracy: 0.921548
# target classifier loss: 2.058351, target accuracy: 0.462893
# 0.9988593685858431
# step:  2390
# source classifier loss: 0.357792, source accuracy: 0.921548
# target classifier loss: 2.058290, target accuracy: 0.462893
# 0.9988944427261528
# step:  2400
# source classifier loss: 0.357788, source accuracy: 0.921548
# target classifier loss: 2.058299, target accuracy: 0.462893
# 0.9989284389233053
# step:  2410
# source classifier loss: 0.357785, source accuracy: 0.921548
# target classifier loss: 2.058253, target accuracy: 0.462893
# 0.9989613902710099
# step:  2420
# source classifier loss: 0.357782, source accuracy: 0.921548
# target classifier loss: 2.058226, target accuracy: 0.462893
# 0.9989933288490944
# step:  2430
# source classifier loss: 0.357779, source accuracy: 0.921548
# target classifier loss: 2.058213, target accuracy: 0.462893
# 0.9990242857544356
# step:  2440
# source classifier loss: 0.357776, source accuracy: 0.921548
# target classifier loss: 2.058250, target accuracy: 0.462893
# 0.9990542911309594
# step:  2450
# source classifier loss: 0.357772, source accuracy: 0.921548
# target classifier loss: 2.058283, target accuracy: 0.462893
# 0.99908337419873
# step:  2460
# source classifier loss: 0.357768, source accuracy: 0.921548
# target classifier loss: 2.058335, target accuracy: 0.462893
# 0.999111563282157
# step:  2470
# source classifier loss: 0.357764, source accuracy: 0.921548
# target classifier loss: 2.058374, target accuracy: 0.462893
# 0.9991388858373509
# step:  2480
# source classifier loss: 0.357761, source accuracy: 0.921548
# target classifier loss: 2.058412, target accuracy: 0.462893
# 0.9991653684786446
# step:  2490
# source classifier loss: 0.357757, source accuracy: 0.921548
# target classifier loss: 2.058445, target accuracy: 0.462893
# 0.9991910370043158
# step:  2500
# source classifier loss: 0.357754, source accuracy: 0.921548
# target classifier loss: 2.058423, target accuracy: 0.462893
# 0.9992159164215246
# step:  2510
# source classifier loss: 0.357753, source accuracy: 0.921548
# target classifier loss: 2.058422, target accuracy: 0.462893
# 0.9992400309704961
# step:  2520
# source classifier loss: 0.357753, source accuracy: 0.921548
# target classifier loss: 2.058424, target accuracy: 0.462893
# 0.999263404147968
# step:  2530
# source classifier loss: 0.357753, source accuracy: 0.921548
# target classifier loss: 2.058426, target accuracy: 0.462893
# 0.9992860587299246
# step:  2540
# source classifier loss: 0.357753, source accuracy: 0.921548
# target classifier loss: 2.058424, target accuracy: 0.462893
# 0.9993080167936437
# step:  2550
# source classifier loss: 0.357753, source accuracy: 0.921548
# target classifier loss: 2.058423, target accuracy: 0.462893
# 0.9993292997390673
# step:  2560
# source classifier loss: 0.357753, source accuracy: 0.921548
# target classifier loss: 2.058423, target accuracy: 0.462893
# 0.9993499283095266
# step:  2570
# source classifier loss: 0.357753, source accuracy: 0.921548
# target classifier loss: 2.058423, target accuracy: 0.462893
# 0.9993699226118375
# step:  2580
# source classifier loss: 0.357753, source accuracy: 0.921548
# target classifier loss: 2.058422, target accuracy: 0.462893
# 0.999389302135776
# step:  2590
# source classifier loss: 0.357753, source accuracy: 0.921548
# target classifier loss: 2.058422, target accuracy: 0.462893
# 0.9994080857729739
# step:  2600
# source classifier loss: 0.357752, source accuracy: 0.921548
# target classifier loss: 2.058423, target accuracy: 0.462893
# 0.999426291835225
# step:  2610
# source classifier loss: 0.357752, source accuracy: 0.921548
# target classifier loss: 2.058424, target accuracy: 0.462893
# 0.9994439380722449
# step:  2620
# source classifier loss: 0.357752, source accuracy: 0.921548
# target classifier loss: 2.058425, target accuracy: 0.462893
# 0.9994610416888825
# step:  2630
# source classifier loss: 0.357752, source accuracy: 0.921548
# target classifier loss: 2.058425, target accuracy: 0.462893
# 0.9994776193618087
# step:  2640
# source classifier loss: 0.357752, source accuracy: 0.921548
# target classifier loss: 2.058424, target accuracy: 0.462893
# 0.9994936872556979
# step:  2650
# source classifier loss: 0.357752, source accuracy: 0.921548
# target classifier loss: 2.058426, target accuracy: 0.462893
# 0.9995092610389145
# step:  2660
# source classifier loss: 0.357752, source accuracy: 0.921548
# target classifier loss: 2.058427, target accuracy: 0.462893
# 0.9995243558987195
# step:  2670
# source classifier loss: 0.357751, source accuracy: 0.921548
# target classifier loss: 2.058428, target accuracy: 0.462893
# 0.9995389865560136
# step:  2680
# source classifier loss: 0.357751, source accuracy: 0.921548
# target classifier loss: 2.058426, target accuracy: 0.462893
# 0.9995531672796345
# step:  2690
# source classifier loss: 0.357751, source accuracy: 0.921548
# target classifier loss: 2.058426, target accuracy: 0.462893
# 0.9995669119002097
# step:  2700
# source classifier loss: 0.357751, source accuracy: 0.921548
# target classifier loss: 2.058427, target accuracy: 0.462893
# 0.9995802338235937
# step:  2710
# source classifier loss: 0.357751, source accuracy: 0.921548
# target classifier loss: 2.058427, target accuracy: 0.462893
# 0.9995931460438896
# step:  2720
# source classifier loss: 0.357751, source accuracy: 0.921548
# target classifier loss: 2.058426, target accuracy: 0.462893
# 0.9996056611560755
# step:  2730
# source classifier loss: 0.357751, source accuracy: 0.921548
# target classifier loss: 2.058426, target accuracy: 0.462893
# 0.9996177913682447
# step:  2740
# source classifier loss: 0.357751, source accuracy: 0.921548
# target classifier loss: 2.058426, target accuracy: 0.462893
# 0.9996295485134694
# step:  2750
# source classifier loss: 0.357751, source accuracy: 0.921548
# target classifier loss: 2.058425, target accuracy: 0.462893
# 0.9996409440613065
# step:  2760
# source classifier loss: 0.357750, source accuracy: 0.921548
# target classifier loss: 2.058425, target accuracy: 0.462893
# 0.9996519891289457
# step:  2770
# source classifier loss: 0.357750, source accuracy: 0.921548
# target classifier loss: 2.058425, target accuracy: 0.462893
# 0.9996626944920217
# step:  2780
# source classifier loss: 0.357750, source accuracy: 0.921548
# target classifier loss: 2.058425, target accuracy: 0.462893
# 0.9996730705950918
# step:  2790
# source classifier loss: 0.357750, source accuracy: 0.921548
# target classifier loss: 2.058424, target accuracy: 0.462893
# 0.999683127561795
# step:  2800
# source classifier loss: 0.357750, source accuracy: 0.921548
# target classifier loss: 2.058424, target accuracy: 0.462893
# 0.9996928752047007
# step:  2810
# source classifier loss: 0.357750, source accuracy: 0.921548
# target classifier loss: 2.058424, target accuracy: 0.462893
# 0.9997023230348541
# step:  2820
# source classifier loss: 0.357750, source accuracy: 0.921548
# target classifier loss: 2.058425, target accuracy: 0.462893
# 0.9997114802710303
# step:  2830
# source classifier loss: 0.357750, source accuracy: 0.921548
# target classifier loss: 2.058425, target accuracy: 0.462893
# 0.9997203558487056
# step:  2840
# source classifier loss: 0.357750, source accuracy: 0.921548
# target classifier loss: 2.058425, target accuracy: 0.462893
# 0.9997289584287516
# step:  2850
# source classifier loss: 0.357749, source accuracy: 0.921548
# target classifier loss: 2.058425, target accuracy: 0.462893
# 0.9997372964058695
# step:  2860
# source classifier loss: 0.357749, source accuracy: 0.921548
# target classifier loss: 2.058425, target accuracy: 0.462893
# 0.9997453779167558
# step:  2870
# source classifier loss: 0.357749, source accuracy: 0.921548
# target classifier loss: 2.058426, target accuracy: 0.462893
# 0.9997532108480274
# step:  2880
# source classifier loss: 0.357749, source accuracy: 0.921548
# target classifier loss: 2.058426, target accuracy: 0.462893
# 0.9997608028438996
# step:  2890
# source classifier loss: 0.357749, source accuracy: 0.921548
# target classifier loss: 2.058428, target accuracy: 0.462893
# 0.9997681613136271
# step:  2900
# source classifier loss: 0.357749, source accuracy: 0.921548
# target classifier loss: 2.058430, target accuracy: 0.462893
# 0.9997752934387225
# step:  2910
# source classifier loss: 0.357749, source accuracy: 0.921548
# target classifier loss: 2.058429, target accuracy: 0.462893
# 0.9997822061799468
# step:  2920
# source classifier loss: 0.357748, source accuracy: 0.921548
# target classifier loss: 2.058429, target accuracy: 0.462893
# 0.9997889062840914
# step:  2930
# source classifier loss: 0.357748, source accuracy: 0.921548
# target classifier loss: 2.058429, target accuracy: 0.462893
# 0.9997954002905483
# step:  2940
# source classifier loss: 0.357748, source accuracy: 0.921548
# target classifier loss: 2.058429, target accuracy: 0.462893
# 0.9998016945376818
# step:  2950
# source classifier loss: 0.357748, source accuracy: 0.921548
# target classifier loss: 2.058428, target accuracy: 0.462893
# 0.999807795169001
# step:  2960
# source classifier loss: 0.357748, source accuracy: 0.921548
# target classifier loss: 2.058426, target accuracy: 0.462893
# 0.9998137081391485
# step:  2970
# source classifier loss: 0.357748, source accuracy: 0.921548
# target classifier loss: 2.058425, target accuracy: 0.462893
# 0.9998194392196993
# step:  2980
# source classifier loss: 0.357748, source accuracy: 0.921548
# target classifier loss: 2.058427, target accuracy: 0.462893
# 0.9998249940047867
# step:  2990
# source classifier loss: 0.357748, source accuracy: 0.921548
# target classifier loss: 2.058428, target accuracy: 0.462893
# 0.9998303779165529
# step:  3000
# source classifier loss: 0.357747, source accuracy: 0.921548
# target classifier loss: 2.058428, target accuracy: 0.462893
# 0.9998355962104328
# step:  3010
# source classifier loss: 0.357747, source accuracy: 0.921548
# target classifier loss: 2.058428, target accuracy: 0.462893
# 0.9998406539802782
# step:  3020
# source classifier loss: 0.357747, source accuracy: 0.921548
# target classifier loss: 2.058428, target accuracy: 0.462893
# 0.9998455561633188
# step:  3030
# source classifier loss: 0.357748, source accuracy: 0.921548
# target classifier loss: 2.058428, target accuracy: 0.462893
# 0.999850307544979
# step:  3040
# source classifier loss: 0.357748, source accuracy: 0.921548
# target classifier loss: 2.058428, target accuracy: 0.462893
# 0.9998549127635394
# step:  3050
# source classifier loss: 0.357748, source accuracy: 0.921548
# target classifier loss: 2.058428, target accuracy: 0.462893
# 0.9998593763146617
# step:  3060
# source classifier loss: 0.357747, source accuracy: 0.921548
# target classifier loss: 2.058428, target accuracy: 0.462893
# 0.9998637025557675
# step:  3070
# source classifier loss: 0.357747, source accuracy: 0.921548
# target classifier loss: 2.058428, target accuracy: 0.462893
# 0.9998678957102909
# step:  3080
# source classifier loss: 0.357747, source accuracy: 0.921548
# target classifier loss: 2.058428, target accuracy: 0.462893
# 0.9998719598717924
# step:  3090
# source classifier loss: 0.357747, source accuracy: 0.921548
# target classifier loss: 2.058428, target accuracy: 0.462893
# 0.9998758990079541
# step:  3100
# source classifier loss: 0.357748, source accuracy: 0.921548
# target classifier loss: 2.058428, target accuracy: 0.462893
# 0.9998797169644462
# step:  3110
# source classifier loss: 0.357747, source accuracy: 0.921548
# target classifier loss: 2.058428, target accuracy: 0.462893
# 0.9998834174686777
# step:  3120
# source classifier loss: 0.357747, source accuracy: 0.921548
# target classifier loss: 2.058428, target accuracy: 0.462893
# 0.9998870041334327
# step:  3130
# source classifier loss: 0.357748, source accuracy: 0.921548
# target classifier loss: 2.058428, target accuracy: 0.462893
# 0.999890480460391
# step:  3140
# source classifier loss: 0.357747, source accuracy: 0.921548
# target classifier loss: 2.058428, target accuracy: 0.462893
# 0.9998938498435468
# step:  3150
# source classifier loss: 0.357747, source accuracy: 0.921548
# target classifier loss: 2.058428, target accuracy: 0.462893
# 0.9998971155725158
# step:  3160
# source classifier loss: 0.357747, source accuracy: 0.921548
# target classifier loss: 2.058428, target accuracy: 0.462893
# 0.9999002808357453
# step:  3170
# source classifier loss: 0.357747, source accuracy: 0.921548
# target classifier loss: 2.058428, target accuracy: 0.462893
# 0.9999033487236255
# step:  3180
# source classifier loss: 0.357747, source accuracy: 0.921548
# target classifier loss: 2.058428, target accuracy: 0.462893
# 0.9999063222315012
# step:  3190
# source classifier loss: 0.357747, source accuracy: 0.921548
# target classifier loss: 2.058428, target accuracy: 0.462893
# CPU times: user 3min 16s, sys: 26.9 s, total: 3min 43s
# Wall time: 3min 45s

# %% [markdown]
# fig = plt.figure()
# ax1 = fig.add_subplot(211)
# fig.subplots_adjust(bottom=0.2)
# line1 = ax1.plot(acc['src'],'b',label='Source Accuracy')
# line2 = ax1.plot(acc['tar'],'g',label='Target Accuracy')
# ax1.set_ylim(0,1)
# lines = line1+line2
# labels = [l.get_label() for l in lines]
# ax1.legend(lines, labels, loc=(0,-0.4), ncol=2)
# plt.show()
