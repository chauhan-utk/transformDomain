# %% [markdown]
# Domain Adaptation using WDGRL architecture

# %%
# %set_env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %set_env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=1

# %%
# %matplotlib notebook
from config import domainData
from config import num_classes as NUM_CLASSES
from torchvision import datasets, models, transforms
import yaml
import numpy as np
import matplotlib.pyplot as plt
import pickle as pkl
import logit
from random import shuffle
import math
import utils

# %%
import torch
import torch.nn as nn
import torch.autograd as autograd
import torch.optim as optim
from torch.autograd import Variable

# %%
# src_pkl = domainData['amazon_resnet50']
# tar_pkl = domainData['webcam_resnet50']
src_pkl = "./amazon_alexnet_4096.pkl"
tar_pkl = "./webcam_alexnet_4096.pkl"
# src_pkl = './amazon_4096.yml'
# tar_pkl = './webcam_4096.yml'

# %%
with open(src_pkl, 'rb') as f:
    src_data = pkl.load(f)
with open(tar_pkl, 'rb') as f:
    tar_data = pkl.load(f)

# with open(src_pkl, 'r') as f:
#     source = yaml.load(f)
# with open(tar_pkl, 'r') as f:
#     target = yaml.load(f)

# %% [markdown]
# def batch_generator(data, batch_size, shuffle=True):
#     len_data = len(data['features'])
#     def shuffle_data():
#         nonlocal len_data
#         idx = list(range(len_data))
#         idx = np.random.permutation(idx)
#         t_features = [data['features'][i] for i in idx]
#         t_labels = [data['labels'][i] for i in idx]
#         data['features'] = t_features
#         data['labels'] = t_labels
#     if shuffle:
#         shuffle_data()
#     batch_count = 0
#     while True:
#         if batch_count * batch_size + batch_size >= len_data:
#             batch_count = 0
#             if shuffle:
#                 shuffle_data()
#         start = (int) (batch_count * batch_size)
#         end = (int) (start + batch_size)
#         batch_count += 1
#         yield torch.stack(data['features'][start:end]), np.vstack(src_data['labels'][start:end])

# %%
wd_param = 0.1
gp_param = 10
lr_wd_D = 1e-3
D_train_num = 50

l2_param = 1e-5
lr = 1e-3
batch_size = 64
num_steps = 1800
num_class = 31
n_input = 4096
n_hidden = [2048, 1024, 512, 256]
lr_sch = None

use_gpu = True

# %%
xs, ys = src_data['features'], src_data['labels']
xt, yt = tar_data['features'], tar_data['labels']
ys = ys.squeeze()
yt = yt.squeeze()
# xs = source['train']
# ys = source['train_labels']
# xt = target['train']
# yt = target['train_labels']

# %%
class _Generator(nn.Module):
    def __init__(self, act=nn.ReLU(inplace=True)):
        super(_Generator, self).__init__()
        self.h1 = nn.Sequential(nn.Linear(n_input, n_hidden[0]), act,
                                nn.Linear(n_hidden[0], n_hidden[1]), act,
                                nn.Linear(n_hidden[1], n_hidden[2]), act,
                                nn.Linear(n_hidden[2], n_hidden[3]), act
                                )
        utils.weight_init(self.h1)

    def forward(self, x):
        out = self.h1(x)
        return out

class _Classifier(nn.Module):
    """
    Using nn.CrossEntropyLoss() for tf.nn.softmax_cross_entropy_with_logits()
    There is difference in target labels. This loss requires target labels
    in range [0,C-1] instead of one-hot-encoding, as required in tensorflow.
    Also, CrossEntropyLoss() uses LogSoftmax instead of normal Softmax.
    """
    def __init__(self, act=nn.ReLU(inplace=True)):
        super(_Classifier, self).__init__()
        self.h = nn.Sequential(nn.Linear(n_hidden[-1], 128), act,
                               nn.Linear(128, 64), act,
                               nn.Linear(64, num_class))
        utils.weight_init(self.h)

    def forward(self, x):
        out = self.h(x)
        return out

class _Critic(nn.Module):
    def __init__(self, act=nn.ReLU(inplace=True)):
        super(_Critic, self).__init__()
        self.h1 = nn.Sequential(nn.Linear(n_hidden[-1], 128), act,
                               nn.Linear(128, 64), act,
                               nn.Linear(64, 1))
        utils.weight_init(self.h1)

    def forward(self, x):
        out = self.h1(x)
        return out

class Model(object):
    def __init__(self):
        self.cr = _Critic()
        self.gen = _Generator()
        self.cls = _Classifier()

# %%
model = Model()
model.cr = model.cr.cuda() if use_gpu else model.cr
model.gen = model.gen.cuda() if use_gpu else model.gen
model.cls = model.cls.cuda() if use_gpu else model.cls

# %%
# cls_criterion = nn.CrossEntropyLoss()
cls_criterion = utils.softmax_cross_entropy_with_logits(num_class)
l2_reg = utils.L2_Loss()
softmax_ = nn.Softmax(dim=1)

params_wd = [
{'params': model.cr.parameters(), 'lr': lr_wd_D}
]
# wd_d_op = optim.SGD(params_wd, momentum=0.9)
wd_d_op = optim.Adam(params_wd)

params = [
{'params': model.gen.parameters(), 'lr': lr},    
{'params': model.cls.parameters(), 'lr': lr}
]
train_op = optim.SGD(params, momentum=0.9)
# train_op = optim.Adam(params)
lr_sch = optim.lr_scheduler.ExponentialLR(train_op, 0.1)
# lr_sch = optim.lr_scheduler.StepLR(train_op, 200, 0.1)

# %% [markdown]
# S_batches = batch_generator(src_data, batch_size)
# xs_batch, ys_batch = next(S_batches)

# %%
def test(i, acc):
    XS = torch.from_numpy(xs).float()
    XS = XS.cuda() if use_gpu else XS
    y_true = torch.from_numpy(ys).long()
    y_true = y_true.cuda() if use_gpu else y_true
    
    XS = Variable(XS, volatile=True)
    y_true = Variable(y_true, requires_grad=False)
    
    h2 = model.gen(XS)
    logits = model.cls(h2)
    clf_loss = cls_criterion(logits, y_true)
    logits = softmax_(logits)
    _, pred_idx = torch.max(logits, 1)
    clf_acc = torch.eq(pred_idx, y_true).float().mean()
#     clf_acc = torch.sum(pred_idx == y_true) / y_true.size(0)
    print('step: ', i)
    print('source classifier loss: %f, source accuracy: %f' % (clf_loss, clf_acc))
    acc['src'].append(clf_acc.cpu().data.numpy())

    XS = torch.from_numpy(xt).float()
    XS = XS.cuda() if use_gpu else XS
    y_true = torch.from_numpy(yt).long()
    y_true = y_true.cuda() if use_gpu else y_true
    
    XS = Variable(XS, volatile=True)
    y_true = Variable(y_true, requires_grad=False)
    
    h2 = model.gen(XS)
    logits = model.cls(h2)
    clf_loss = cls_criterion(logits, y_true)
    logits = softmax_(logits)
    _, pred_idx = torch.max(logits, 1)
    clf_acc = torch.eq(pred_idx, y_true).float().mean()
#     clf_acc = torch.sum(pred_idx == y_true) / y_true.size(0)
    print('target classifier loss: %f, target accuracy: %f' % (clf_loss, clf_acc))
#     ax.plot(clf_acc)
    acc['tar'].append(clf_acc.cpu().data.numpy())

# %%
acc = { 'src': [], 'tar': [] }

def train():

    # put all network in training mode
    model.gen.train()
    model.cr.train()
    model.cls.train()

    S_batches = utils.batch_generator([xs, ys], batch_size / 2)

    for i in range(num_steps):
        xs_batch, ys_batch = next(S_batches)
        xb = xs_batch
        
        train_op.zero_grad()        
        XB = torch.from_numpy(xb).float()
        ys_batch = torch.from_numpy(ys_batch).long()
        if use_gpu:
            XB = XB.cuda()
            ys_batch = ys_batch.cuda()
        XB = Variable(XB)
        ys_batch = Variable(ys_batch, requires_grad=False)
        
        XB = model.gen(XB)
        pred_logit = model.cls(XB)
        clf_loss = cls_criterion(pred_logit, ys_batch)
        
        l2_loss = None
        for name, param in model.gen.named_parameters():
            if 'weight' in name:
                if l2_loss is None:
                    l2_loss = l2_reg(param) * l2_param
                else:
                    l2_loss += l2_reg(param) * l2_param
        for name, param in model.cr.named_parameters():
            if 'weight' in name:	
                l2_loss += l2_reg(param) * l2_param

        total_loss = clf_loss + l2_loss
        # total_loss = clf_loss + wd_param * wd_loss
        total_loss.backward()
        train_op.step()
        
        if i % 500 == 0 and lr_sch is not None:
            lr_sch.step()
        
        if i % 10 == 0:
            test(i, acc)

# %%
train()
# Out:
# step:  0
# source classifier loss: 5.084923, source accuracy: 0.045438
# target classifier loss: 4.674077, target accuracy: 0.036478
# step:  10
# source classifier loss: 3.736034, source accuracy: 0.055023
# target classifier loss: 3.724208, target accuracy: 0.033962
# step:  20
# source classifier loss: 3.212682, source accuracy: 0.138445
# target classifier loss: 3.343492, target accuracy: 0.085535
# step:  30
# source classifier loss: 3.019206, source accuracy: 0.208378
# target classifier loss: 3.331100, target accuracy: 0.104403
# step:  40
# source classifier loss: 3.012053, source accuracy: 0.166134
# target classifier loss: 3.217976, target accuracy: 0.118239
# step:  50
# source classifier loss: 2.786849, source accuracy: 0.272985
# target classifier loss: 3.118044, target accuracy: 0.134591
# step:  60
# source classifier loss: 2.523650, source accuracy: 0.340078
# target classifier loss: 2.946956, target accuracy: 0.176101
# step:  70
# source classifier loss: 2.482185, source accuracy: 0.315229
# target classifier loss: 2.970582, target accuracy: 0.174843
# step:  80
# source classifier loss: 2.308394, source accuracy: 0.373092
# target classifier loss: 2.840272, target accuracy: 0.218868
# step:  90
# source classifier loss: 2.059935, source accuracy: 0.441960
# target classifier loss: 2.675586, target accuracy: 0.281761
# step:  100
# source classifier loss: 1.857103, source accuracy: 0.500533
# target classifier loss: 2.702785, target accuracy: 0.271698
# step:  110
# source classifier loss: 2.174243, source accuracy: 0.397231
# target classifier loss: 3.084203, target accuracy: 0.168553
# step:  120
# source classifier loss: 1.821527, source accuracy: 0.489883
# target classifier loss: 2.644754, target accuracy: 0.260377
# step:  130
# source classifier loss: 1.715009, source accuracy: 0.534256
# target classifier loss: 2.541873, target accuracy: 0.320755
# step:  140
# source classifier loss: 1.530195, source accuracy: 0.576500
# target classifier loss: 2.362856, target accuracy: 0.364780
# step:  150
# source classifier loss: 1.550078, source accuracy: 0.562300
# target classifier loss: 2.528443, target accuracy: 0.320755
# step:  160
# source classifier loss: 1.513925, source accuracy: 0.572240
# target classifier loss: 2.414093, target accuracy: 0.367296
# step:  170
# source classifier loss: 1.587230, source accuracy: 0.539936
# target classifier loss: 2.521397, target accuracy: 0.320755
# step:  180
# source classifier loss: 1.534438, source accuracy: 0.555556
# target classifier loss: 2.605090, target accuracy: 0.289308
# step:  190
# target classifier loss: 2.154384, target accuracy: 0.466667
# step:  750
# source classifier loss: 0.463576, source accuracy: 0.876819
# target classifier loss: 2.177640, target accuracy: 0.466667
# step:  760
# source classifier loss: 0.460390, source accuracy: 0.880724
# target classifier loss: 2.154097, target accuracy: 0.467925
# step:  770
# source classifier loss: 0.453396, source accuracy: 0.878594
# target classifier loss: 2.122274, target accuracy: 0.471698
# step:  780
# source classifier loss: 0.451884, source accuracy: 0.878594
# target classifier loss: 2.111971, target accuracy: 0.470440
# step:  790
# source classifier loss: 0.446448, source accuracy: 0.884629
# target classifier loss: 2.134158, target accuracy: 0.469182
# step:  800
# source classifier loss: 0.441249, source accuracy: 0.888534
# target classifier loss: 2.147089, target accuracy: 0.462893
# step:  810
# source classifier loss: 0.438804, source accuracy: 0.886759
# target classifier loss: 2.176696, target accuracy: 0.462893
# step:  820
# source classifier loss: 0.435426, source accuracy: 0.886404
# target classifier loss: 2.159120, target accuracy: 0.466667
# step:  830
# source classifier loss: 0.434577, source accuracy: 0.888889
# target classifier loss: 2.153891, target accuracy: 0.469182
# step:  840
# source classifier loss: 0.431065, source accuracy: 0.889599
# target classifier loss: 2.156648, target accuracy: 0.459119
# step:  850
# source classifier loss: 0.426775, source accuracy: 0.886759
# target classifier loss: 2.157585, target accuracy: 0.455346
# step:  860
# source classifier loss: 0.423695, source accuracy: 0.890664
# target classifier loss: 2.168081, target accuracy: 0.457862
# step:  870
# source classifier loss: 0.422472, source accuracy: 0.893504
# target classifier loss: 2.183012, target accuracy: 0.467925
# step:  880
# source classifier loss: 0.413940, source accuracy: 0.896699
# target classifier loss: 2.138725, target accuracy: 0.461635
# step:  890
# source classifier loss: 0.415199, source accuracy: 0.890309
# target classifier loss: 2.151298, target accuracy: 0.452830
# step:  900
# source classifier loss: 0.411896, source accuracy: 0.897054
# target classifier loss: 2.159904, target accuracy: 0.454088
# step:  910
# source classifier loss: 0.410178, source accuracy: 0.896699
# target classifier loss: 2.147457, target accuracy: 0.452830
# step:  920
# source classifier loss: 0.408611, source accuracy: 0.895989
# target classifier loss: 2.168307, target accuracy: 0.460377
# step:  930
# source classifier loss: 0.403733, source accuracy: 0.898829
# target classifier loss: 2.189497, target accuracy: 0.450314
# step:  940
# source classifier loss: 0.401376, source accuracy: 0.899894
# target classifier loss: 2.203474, target accuracy: 0.454088
# step:  950
# source classifier loss: 0.403493, source accuracy: 0.899184
# target classifier loss: 2.207968, target accuracy: 0.454088
# step:  960
# source classifier loss: 0.396498, source accuracy: 0.903443
# target classifier loss: 2.157608, target accuracy: 0.469182
# step:  970
# source classifier loss: 0.395302, source accuracy: 0.899539
# target classifier loss: 2.128375, target accuracy: 0.476730
# step:  980
# source classifier loss: 0.391774, source accuracy: 0.905928
# target classifier loss: 2.121312, target accuracy: 0.477987
# step:  990
# source classifier loss: 0.393352, source accuracy: 0.903088
# target classifier loss: 2.153972, target accuracy: 0.456604
# step:  1000
# source classifier loss: 0.387098, source accuracy: 0.905573
# target classifier loss: 2.191263, target accuracy: 0.460377
# step:  1010
# source classifier loss: 0.386543, source accuracy: 0.905573
# target classifier loss: 2.193134, target accuracy: 0.461635
# step:  1020
# target classifier loss: 2.174737, target accuracy: 0.455346
# step:  1570
# source classifier loss: 0.367334, source accuracy: 0.914448
# target classifier loss: 2.174942, target accuracy: 0.455346
# step:  1580
# source classifier loss: 0.367304, source accuracy: 0.914093
# target classifier loss: 2.174812, target accuracy: 0.455346
# step:  1590
# source classifier loss: 0.367271, source accuracy: 0.914093
# target classifier loss: 2.174476, target accuracy: 0.455346
# step:  1600
# source classifier loss: 0.367250, source accuracy: 0.914093
# target classifier loss: 2.174265, target accuracy: 0.455346
# step:  1610
# source classifier loss: 0.367222, source accuracy: 0.914448
# target classifier loss: 2.174118, target accuracy: 0.455346
# step:  1620
# source classifier loss: 0.367183, source accuracy: 0.914093
# target classifier loss: 2.174200, target accuracy: 0.455346
# step:  1630
# source classifier loss: 0.367152, source accuracy: 0.913738
# target classifier loss: 2.174453, target accuracy: 0.455346
# step:  1640
# source classifier loss: 0.367125, source accuracy: 0.913738
# target classifier loss: 2.174475, target accuracy: 0.455346
# step:  1650
# source classifier loss: 0.367099, source accuracy: 0.913738
# target classifier loss: 2.174515, target accuracy: 0.455346
# step:  1660
# source classifier loss: 0.367073, source accuracy: 0.913738
# target classifier loss: 2.174076, target accuracy: 0.455346
# step:  1670
# source classifier loss: 0.367046, source accuracy: 0.913738
# target classifier loss: 2.173851, target accuracy: 0.455346
# step:  1680
# source classifier loss: 0.367021, source accuracy: 0.914448
# target classifier loss: 2.174193, target accuracy: 0.455346
# step:  1690
# source classifier loss: 0.366997, source accuracy: 0.914448
# target classifier loss: 2.174420, target accuracy: 0.455346
# step:  1700
# source classifier loss: 0.366970, source accuracy: 0.913738
# target classifier loss: 2.174665, target accuracy: 0.455346
# step:  1710
# source classifier loss: 0.366942, source accuracy: 0.913738
# target classifier loss: 2.174555, target accuracy: 0.455346
# step:  1720
# source classifier loss: 0.366913, source accuracy: 0.913383
# target classifier loss: 2.174541, target accuracy: 0.455346
# step:  1730
# source classifier loss: 0.366887, source accuracy: 0.914093
# target classifier loss: 2.174454, target accuracy: 0.455346
# step:  1740
# source classifier loss: 0.366862, source accuracy: 0.914448
# target classifier loss: 2.174264, target accuracy: 0.455346
# step:  1750
# source classifier loss: 0.366837, source accuracy: 0.914448
# target classifier loss: 2.174289, target accuracy: 0.455346
# step:  1760
# source classifier loss: 0.366808, source accuracy: 0.914093
# target classifier loss: 2.174061, target accuracy: 0.455346
# step:  1770
# source classifier loss: 0.366782, source accuracy: 0.914093
# target classifier loss: 2.173656, target accuracy: 0.455346
# step:  1780
# source classifier loss: 0.366757, source accuracy: 0.914093
# target classifier loss: 2.173540, target accuracy: 0.455346
# step:  1790
# source classifier loss: 0.366733, source accuracy: 0.913738
# target classifier loss: 2.173544, target accuracy: 0.455346

# %% [markdown]
# fig = plt.figure()
# ax1 = fig.add_subplot(211)
# fig.subplots_adjust(bottom=0.2)
# line1 = ax1.plot(acc['src'],'b',label='Source Accuracy')
# line2 = ax1.plot(acc['tar'],'g',label='Target Accuracy')
# ax1.set_ylim(0,1)
# lines = line1+line2
# labels = [l.get_label() for l in lines]
# ax1.legend(lines, labels, loc=(0,-0.4), ncol=2)
# plt.show()
