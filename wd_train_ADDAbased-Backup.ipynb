# %%
# Code taken from here : http://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html

import os

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
from config import domainData
from config import num_classes as NUM_CLASSES
from wdStackDomain_alexnet import WDDomain
from logger import Logger
import torch
import torch.nn as nn
import torch.autograd as autograd
import torch.nn.init as init
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.autograd import Variable
from torch.autograd import Function
import torch.nn.functional as F
import numpy as np
import logit
import torchvision
from torchvision import datasets, models, transforms
import time
import random
import copy
import datetime
import itertools
from tqdm import *

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
#         transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# %%
def get_log_dir(path, log_dir):
    path = path + '/' + log_dir
    os.makedirs(path, exist_ok=True)
    return path

# %%
use_gpu = True and torch.cuda.is_available()
train_dir = domainData['amazon'] # 'amazon', 'dslr', 'webcam'
val_dir = domainData['webcam']
num_classes = NUM_CLASSES['office']
wd_param = 0.1
gp_lambda = 10
num_iters = 75 # total number of training iterations
num_cls_train = 2 # epochs to train classifier
num_gen_train = 1 # epochs to train generator
base_lr = 1e-5
l2_param = 1e-5
g_loss_param = 0.2
EPOCHS=50
batch_size = 64 # batch_size for each of source and target samples
load_cls = False
log = False
text_log = True
exp_name = 'wd_tr_2step_Rsnt2blk_r3'

# %%
if log:
    log_dir = get_log_dir('./logs', exp_name)
    logger = Logger(log_dir)
if text_log:
    f_name = "./test_logs/run_at_"+datetime.datetime.fromtimestamp(time.time()).strftime("%d-%m-%Y_%H:%M:%S")+".txt"
    text_file = open(f_name, 'w+')
print("use gpu: ", use_gpu)

torch.manual_seed(7)
if use_gpu:
    torch.cuda.manual_seed(7)
# Out:
# use gpu:  True

# %%
image_datasets = {'train' : datasets.ImageFolder(train_dir,
                                          data_transforms['train']),
                  'val' : datasets.ImageFolder(val_dir,
                                          data_transforms['val'])
                 }
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size,
                                             shuffle=True, num_workers=4, drop_last=True)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

model_ft = WDDomain(num_classes)

if load_cls:
    model_ft.load_cls()

if use_gpu:
    model_ft = model_ft.cuda()

# %%
def get_inifinite_dataloader(dataloader):
    data_iter = iter(dataloader)
    while(1):
        try:
            data = next(data_iter)
            yield data
        except StopIteration:
            data_iter = iter(dataloader)

# %%
# clscriterion = nn.CrossEntropyLoss()
clscriterion = logit.softmax_cross_entropy_with_logits(num_classes)

param_group1 = [
{'params' : model_ft._discriminator.parameters(), 'lr': 10*base_lr, 'weight_decay' : 1e-5 } # , 'lr' : 1e-4, 'betas' : (0.5, 0.9)
]
# disc_opt = optim.Adam(param_group1)
# disc_opt = optim.ASGD(param_group1)
disc_opt = optim.SGD(param_group1, momentum=0.9)

param_group2 = [
{'params' : model_ft.features.net.features.parameters(), 'lr' : 0.01 * base_lr,
 'weight_decay' : 1e-5},
{'params' : model_ft.features.net.classifier.parameters(), 'lr' : base_lr, 'weight_decay' : 1e-5}, # , 'betas' : (0.5, 0.9
{'params' : model_ft.features.extra.parameters(), 'lr' : 10*base_lr, 'weight_decay' : 1e-5}
]
# gen_opt = optim.Adam(param_group2)
# gen_opt = optim.ASGD(param_group2)
gen_opt = optim.SGD(param_group2, momentum=0.9)

param_group3 = [
{'params' : model_ft.features.net.features.parameters(), 'lr' : 0.01 * base_lr,
 'weight_decay' : 1e-5},
{'params' : model_ft.features.net.classifier.parameters(), 'lr' : base_lr, 'weight_decay' : 1e-5}, # , 'betas' : (0.5, 0.9
{'params' : model_ft.features.extra.parameters(), 'lr' : 10*base_lr, 'weight_decay' : 1e-5},
{'params' : model_ft.classifier.parameters(), 'lr': 10*base_lr, 'weight_decay' : 1e-5} # , 'lr' : 1e-4
]
# cls_opt = optim.Adam(param_group3)
# cls_opt = optim.ASGD(param_group3)
cls_opt = optim.SGD(param_group3, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
# tar_lr_scheduler = lr_scheduler.StepLR(taroptimizer, step_size=7, gamma=0.1)

cls_scheduler = None
# cls_scheduler = lr_scheduler.ExponentialLR(cls_opt, 0.1)
gen_scheduler = None
# gen_scheduler = lr_scheduler.ExponentialLR(gen_opt, 0.1)
disc_scheduler = None
# disc_scheduler = lr_scheduler.ExponentialLR(disc_opt, 0.1)

# lr_schedulers = [cls_scheduler, gen_scheduler, disc_scheduler]
lr_schedulers = None

softmax = nn.Softmax(dim=1)
l2_reg = logit.L2_Loss()

# %%
def test_model(model_ft, criterion, save_model=False, save_name=None):
    data_iter = iter(dataloaders['val'])

    model_ft.features.eval()
    model_ft.classifier.eval()
    model_ft._discriminator.eval()
    
    acc_val = 0
    steps = 0.
    for data in data_iter:
        img, lbl = data
        if use_gpu:
            img = img.cuda()
            lbl = lbl.cuda()
        img = Variable(img, volatile=True)
        lbl = Variable(lbl, requires_grad=False)

        feat_out = model_ft.features(img)
        out = model_ft.classifier(feat_out)

        loss = criterion(out, lbl)
        
        out1 = softmax(out)
        _, preds = torch.max(out1.data, 1)
#         print("preds size: ", preds.size(), " lbl data size: ", lbl.data.size())
        acc_val += torch.eq(preds, lbl.data).float().mean()
        steps = steps + 1
    # acc = acc_val / dataset_sizes['val']
    acc = acc_val / steps
    print("validation accuracy: {:.4f}".format(acc))
    if text_log:
        text_file.write("validation accuracy: {:.4f}\n".format(acc))
    if save_model:
        torch.save(model_ft.state_dict(), save_name)
    return

# %%
def train_model(model, clscriterion, disc_opt, gen_opt, cls_opt, lr_schedulers=None, num_epochs=25):
    since = time.time()

    for i in range(num_iters):
        
        running_clsacc, running_clsloss, steps = 0., 0., 0
        
        # train classifier on source
        for _ in range(num_cls_train):
            cls_src = iter(dataloaders['train'])
            for data in cls_src:
                srcimgs, srclbls = data
                
                srcimgs = srcimgs.cuda() if use_gpu else srcimgs
                srclbls = srclbls.cuda() if use_gpu else srclbls
                srcimgs, srclbls = Variable(srcimgs), Variable(srclbls)
                
                outimgs = model.features(srcimgs)
                cls_out = model.classifier(outimgs)
                cls_loss = clscriterion(cls_out, srclbls)
                
#                 l2_loss = None
#                 for name, param in model.classifier.named_parameters():
#                     if 'weight' in name:
#                         if l2_loss is None:
#                             l2_loss = l2_reg(param) * l2_param
#                         else:
#                             l2_loss += l2_reg(param) * l2_param
#                 for name, param in model.features.named_parameters():
#                     if 'weight' in name:
#                         l2_loss += l2_reg(param) * l2_param
                        
                _, preds = torch.max(softmax(cls_out).data, 1)
                running_clsacc += torch.eq(preds, srclbls.data).float().mean()
                running_clsloss += cls_loss.data[0]
                steps = steps + 1
#                 cls_loss_t = cls_loss + l2_loss
                cls_loss_t = cls_loss
                cls_opt.zero_grad()
                cls_loss_t.backward()
                cls_opt.step()
            print("classification loss: {:.4f}, classification acc: {:.4f}".
                  format(running_clsloss/steps, running_clsacc/steps))
                           
        for _ in range(num_gen_train):
            src_data = iter(dataloaders['train'])
            tar_data = get_inifinite_dataloader(dataloaders['val'])
            running_critic_loss, running_gen_loss, running_gp_loss, steps = 0., 0., 0., 0
            
            net = copy.deepcopy(model.features) # copy the network
            for params in net.parameters():
                params.requires_grad=False
            
            for srcinps, srclbls in src_data:
                tarinps, _ = next(tar_data)

                srcinps = srcinps.cuda() if use_gpu else srcinps
                srclbls = srclbls.cuda() if use_gpu else srclbls
                tarinps = tarinps.cuda() if use_gpu else tarinps
                srcinps, srclbls = Variable(srcinps), Variable(srclbls)
                tarinps = Variable(tarinps)

                real_out = net(srcinps)
                gen_out = model.features(tarinps)
                critic_flag = random.randint(0,1)
                critic_in = torch.cat([real_out, gen_out]) if critic_flag else torch.cat([gen_out, real_out])
                critic_out = model._discriminator(critic_in)

                D = critic_out[:batch_size] if critic_flag else critic_out[batch_size:]
                D_ = critic_out[batch_size:] if critic_flag else critic_out[:batch_size]

                critic_loss = (torch.sigmoid(D_) ** 2).mean() + ((1. - torch.sigmoid(D)) ** 2).mean()
                gen_loss = D.mean() - D_.mean()
                
#                 print("critic_loss: ", critic_loss.data)
#                 print("gen_loss: ", gen_loss.data)

                running_critic_loss += critic_loss.data[0]
                running_gen_loss += gen_loss.data[0]

                alpha = torch.Tensor(real_out.size()).uniform_(0,1)
                alpha = alpha.cuda() if use_gpu else alpha
                diff = real_out.data - gen_out.data
                interpolates = real_out.data + (alpha * diff)
                interpolates = Variable(interpolates, requires_grad=True)

                inter_out = model._discriminator(interpolates)
                ones = torch.ones(inter_out.size())
                ones = ones.cuda() if use_gpu else ones

                grads = autograd.grad(inter_out, interpolates, grad_outputs=ones,
                    retain_graph=True, create_graph=True, only_inputs=False)[0]
                gp = ((grads.norm(2, dim=1) - 1) ** 2).mean()

                running_gp_loss += gp.data[0]
#                 print("gp_loss: ", gp.data)

                for params in model._discriminator.parameters():
                    params.requires_grad=True

#                 l2_loss = None
#                 for name, param in model._discriminator.named_parameters():
#                     if 'weight' in name:
#                         if l2_loss is None:
#                             l2_loss = l2_reg(param) * l2_param
#                         else:
#                             l2_loss += l2_reg(param) * l2_param

#                 critic_loss_t = critic_loss + l2_loss + gp * gp_lambda
                critic_loss_t = critic_loss * wd_param + gp * gp_lambda
                disc_opt.zero_grad()
                critic_loss_t.backward(retain_graph=True)
                disc_opt.step()

                for params in model._discriminator.parameters():
                    params.requires_grad=False

#                 l2_loss = None
#                 for name, param in model.features.named_parameters():
#                     if 'weight' in name:
#                         if l2_loss is None:
#                             l2_loss = l2_reg(param) * l2_param
#                         else:
#                             l2_loss += l2_reg(param) * l2_param

#                 gen_loss_t = gen_loss + l2_loss
                gen_loss_t = gen_loss * g_loss_param

                gen_opt.zero_grad()
                gen_loss_t.backward()
                gen_opt.step()
                steps = steps + 1
            
            del net
            
        print("critic loss: {:.4f}, gen loss: {:.4f}, gp loss: {:.4f}".
              format(running_critic_loss/steps, running_gen_loss/steps, running_gp_loss/steps))
            
        if lr_schedulers:
            for x in lr_schedulers:
                if x is not None:
                    x.step()

#             l2_loss = None
#             for name, param in model.classifier.named_parameters():
#                 if 'weight' in name:
#                     if l2_loss is None:
#                         l2_loss = l2_reg(param) * l2_param
#                     else:
#                         l2_loss += l2_reg(param) * l2_param
#             for name, param in model.features.basenet.fc.named_parameters():
#                 if 'weight' in name:
#                     l2_loss += l2_reg(param) * l2_param

#             total_loss = clsloss + l2_loss + g_l * g_loss_param
#             total_loss.backward()
#             cls_opt.step()

        test_model(model, clscriterion, False, None)

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))    
    return

# %%
train_model(model_ft, clscriterion, disc_opt, gen_opt, cls_opt, lr_schedulers, num_epochs=EPOCHS)

save_name = "grl_model_with_transform.pth"
test_model(model_ft, clscriterion, False, save_name)
test_model(model_ft, clscriterion, False, save_name)
test_model(model_ft, clscriterion, False, save_name)
test_model(model_ft, clscriterion, False, save_name)
test_model(model_ft, clscriterion, False, save_name)
# Out:
# classification loss: 3.3009, classification acc: 0.1140
# classification loss: 3.0107, classification acc: 0.2372
# critic loss: 0.5056, gen loss: -0.0190, gp loss: 0.8126
# validation accuracy: 0.3034
# classification loss: 2.2680, classification acc: 0.5387
# classification loss: 2.1149, classification acc: 0.5756
# critic loss: 0.5093, gen loss: -0.0346, gp loss: 0.8119
# validation accuracy: 0.4062
# classification loss: 1.7486, classification acc: 0.6456
# classification loss: 1.6661, classification acc: 0.6639
# critic loss: 0.5119, gen loss: -0.0455, gp loss: 0.8120
# validation accuracy: 0.4596
# classification loss: 1.4590, classification acc: 0.7006
# classification loss: 1.4100, classification acc: 0.7147
# critic loss: 0.5146, gen loss: -0.0563, gp loss: 0.8116
# validation accuracy: 0.4805
# classification loss: 1.2770, classification acc: 0.7351
# classification loss: 1.2476, classification acc: 0.7399
# critic loss: 0.5177, gen loss: -0.0676, gp loss: 0.8111
# validation accuracy: 0.4922
# classification loss: 1.1600, classification acc: 0.7532
# classification loss: 1.1348, classification acc: 0.7571
# critic loss: 0.5210, gen loss: -0.0787, gp loss: 0.8109
# validation accuracy: 0.4948
# classification loss: 1.0718, classification acc: 0.7656
# classification loss: 1.0542, classification acc: 0.7672
# critic loss: 0.5249, gen loss: -0.0913, gp loss: 0.8107
# validation accuracy: 0.5039
# classification loss: 1.0050, classification acc: 0.7724
# classification loss: 0.9888, classification acc: 0.7768
# critic loss: 0.5287, gen loss: -0.1023, gp loss: 0.8099
# validation accuracy: 0.5169
# classification loss: 0.9445, classification acc: 0.7905
# classification loss: 0.9344, classification acc: 0.7896
# critic loss: 0.5332, gen loss: -0.1145, gp loss: 0.8095
# validation accuracy: 0.5117
# classification loss: 0.9012, classification acc: 0.7955
# classification loss: 0.8908, classification acc: 0.7956
# critic loss: 0.5381, gen loss: -0.1266, gp loss: 0.8088
# validation accuracy: 0.5169
# classification loss: 0.8619, classification acc: 0.7976
# classification loss: 0.8526, classification acc: 0.8017
# critic loss: 0.5435, gen loss: -0.1392, gp loss: 0.8085
# validation accuracy: 0.5221
# classification loss: 0.8264, classification acc: 0.8043
# classification loss: 0.8202, classification acc: 0.8084
# critic loss: 0.5494, gen loss: -0.1517, gp loss: 0.8077
# validation accuracy: 0.5260
# classification loss: 0.7957, classification acc: 0.8168
# classification loss: 0.7904, classification acc: 0.8153
# critic loss: 0.5556, gen loss: -0.1634, gp loss: 0.8071
# validation accuracy: 0.5260
# classification loss: 0.7688, classification acc: 0.8196
# classification loss: 0.7618, classification acc: 0.8203
# critic loss: 0.5620, gen loss: -0.1749, gp loss: 0.8065
# validation accuracy: 0.5299
# classification loss: 0.7480, classification acc: 0.8253
# classification loss: 0.7415, classification acc: 0.8228
# critic loss: 0.5695, gen loss: -0.1879, gp loss: 0.8058
# validation accuracy: 0.5299
# classification loss: 0.7233, classification acc: 0.8317
# classification loss: 0.7171, classification acc: 0.8320
# critic loss: 0.5771, gen loss: -0.2002, gp loss: 0.8050
# validation accuracy: 0.5391
# classification loss: 0.7037, classification acc: 0.8295
# classification loss: 0.6987, classification acc: 0.8313
# critic loss: 0.5857, gen loss: -0.2144, gp loss: 0.8045
# validation accuracy: 0.5404
# classification loss: 0.6839, classification acc: 0.8366
# classification loss: 0.6796, classification acc: 0.8359
# critic loss: 0.5937, gen loss: -0.2245, gp loss: 0.8038
# validation accuracy: 0.5286
# classification loss: 0.6681, classification acc: 0.8413
# classification loss: 0.6648, classification acc: 0.8400
# critic loss: 0.6034, gen loss: -0.2386, gp loss: 0.8032
# validation accuracy: 0.5260
# classification loss: 0.6490, classification acc: 0.8448
# classification loss: 0.6436, classification acc: 0.8432
# critic loss: 0.6124, gen loss: -0.2498, gp loss: 0.8023
# validation accuracy: 0.5182
# classification loss: 0.6326, classification acc: 0.8455
# classification loss: 0.6286, classification acc: 0.8461
# critic loss: 0.6221, gen loss: -0.2614, gp loss: 0.8019
# validation accuracy: 0.5156
# classification loss: 0.6157, classification acc: 0.8480
# classification loss: 0.6129, classification acc: 0.8459
# critic loss: 0.6327, gen loss: -0.2750, gp loss: 0.8013
# validation accuracy: 0.5169
# classification loss: 0.6050, classification acc: 0.8519
# classification loss: 0.6017, classification acc: 0.8516
# critic loss: 0.6436, gen loss: -0.2887, gp loss: 0.8007
# validation accuracy: 0.5078
# classification loss: 0.5906, classification acc: 0.8516
# classification loss: 0.5870, classification acc: 0.8533
# critic loss: 0.6545, gen loss: -0.3007, gp loss: 0.8002
# validation accuracy: 0.5104
# classification loss: 0.5745, classification acc: 0.8569
# classification loss: 0.5728, classification acc: 0.8565
# critic loss: 0.6647, gen loss: -0.3089, gp loss: 0.7996
# validation accuracy: 0.5104
# classification loss: 0.5686, classification acc: 0.8580
# classification loss: 0.5615, classification acc: 0.8615
# critic loss: 0.6761, gen loss: -0.3227, gp loss: 0.7992
# validation accuracy: 0.5078
# classification loss: 0.5508, classification acc: 0.8651
# classification loss: 0.5500, classification acc: 0.8640
# critic loss: 0.6871, gen loss: -0.3336, gp loss: 0.7987
# validation accuracy: 0.4935
# classification loss: 0.5406, classification acc: 0.8651
# classification loss: 0.5362, classification acc: 0.8677
# critic loss: 0.6987, gen loss: -0.3456, gp loss: 0.7984
# validation accuracy: 0.5000
# classification loss: 0.5317, classification acc: 0.8654
# classification loss: 0.5263, classification acc: 0.8693
# critic loss: 0.7121, gen loss: -0.3647, gp loss: 0.7979
# validation accuracy: 0.4935
# classification loss: 0.5178, classification acc: 0.8707
# classification loss: 0.5141, classification acc: 0.8722
# critic loss: 0.7228, gen loss: -0.3732, gp loss: 0.7975
# validation accuracy: 0.4961
# classification loss: 0.5061, classification acc: 0.8771
# classification loss: 0.5042, classification acc: 0.8768
# critic loss: 0.7344, gen loss: -0.3839, gp loss: 0.7972
# validation accuracy: 0.4961
# classification loss: 0.4979, classification acc: 0.8817
# classification loss: 0.4930, classification acc: 0.8800
# critic loss: 0.7462, gen loss: -0.3981, gp loss: 0.7969
# validation accuracy: 0.5013
# classification loss: 0.4858, classification acc: 0.8807
# classification loss: 0.4842, classification acc: 0.8805
# critic loss: 0.7576, gen loss: -0.4086, gp loss: 0.7962
# validation accuracy: 0.4961
# classification loss: 0.4779, classification acc: 0.8793
# classification loss: 0.4759, classification acc: 0.8801
# critic loss: 0.7705, gen loss: -0.4281, gp loss: 0.7964
# validation accuracy: 0.4883
# classification loss: 0.4686, classification acc: 0.8853
# classification loss: 0.4653, classification acc: 0.8853
# critic loss: 0.7825, gen loss: -0.4433, gp loss: 0.7959
# validation accuracy: 0.4948
# classification loss: 0.4525, classification acc: 0.8864
# classification loss: 0.4542, classification acc: 0.8857
# critic loss: 0.7934, gen loss: -0.4577, gp loss: 0.7958
# validation accuracy: 0.4896
# classification loss: 0.4486, classification acc: 0.8896
# classification loss: 0.4457, classification acc: 0.8904
# critic loss: 0.8042, gen loss: -0.4670, gp loss: 0.7956
# validation accuracy: 0.4831
# classification loss: 0.4410, classification acc: 0.8910
# classification loss: 0.4380, classification acc: 0.8919
# critic loss: 0.8147, gen loss: -0.4812, gp loss: 0.7953
# validation accuracy: 0.4818
# classification loss: 0.4310, classification acc: 0.8906
# classification loss: 0.4282, classification acc: 0.8933
# critic loss: 0.8251, gen loss: -0.4939, gp loss: 0.7951
# validation accuracy: 0.4831
# classification loss: 0.4241, classification acc: 0.8945
# classification loss: 0.4211, classification acc: 0.8968
# critic loss: 0.8366, gen loss: -0.5144, gp loss: 0.7950
# validation accuracy: 0.4792
# classification loss: 0.4122, classification acc: 0.9034
# classification loss: 0.4119, classification acc: 0.9022
# critic loss: 0.8465, gen loss: -0.5301, gp loss: 0.7949
# validation accuracy: 0.4714
# classification loss: 0.4095, classification acc: 0.8988
# classification loss: 0.4055, classification acc: 0.9011
# critic loss: 0.8565, gen loss: -0.5448, gp loss: 0.7947
# validation accuracy: 0.4766
# classification loss: 0.3989, classification acc: 0.9041
# classification loss: 0.3956, classification acc: 0.9055
# critic loss: 0.8658, gen loss: -0.5640, gp loss: 0.7951
# validation accuracy: 0.4740
# classification loss: 0.3896, classification acc: 0.9077
# classification loss: 0.3883, classification acc: 0.9068
# critic loss: 0.8742, gen loss: -0.5751, gp loss: 0.7948
# validation accuracy: 0.4701
# classification loss: 0.3832, classification acc: 0.9123
# classification loss: 0.3812, classification acc: 0.9114
# critic loss: 0.8831, gen loss: -0.5928, gp loss: 0.7948
# validation accuracy: 0.4674
# classification loss: 0.3787, classification acc: 0.9094
# classification loss: 0.3774, classification acc: 0.9118
# critic loss: 0.8913, gen loss: -0.6062, gp loss: 0.7947
# validation accuracy: 0.4648
# classification loss: 0.3690, classification acc: 0.9130
# classification loss: 0.3701, classification acc: 0.9116
# critic loss: 0.8995, gen loss: -0.6303, gp loss: 0.7947
# validation accuracy: 0.4609
# classification loss: 0.3623, classification acc: 0.9173
# classification loss: 0.3605, classification acc: 0.9180
# critic loss: 0.9072, gen loss: -0.6516, gp loss: 0.7947
# validation accuracy: 0.4648
# classification loss: 0.3565, classification acc: 0.9169
# classification loss: 0.3557, classification acc: 0.9176
# critic loss: 0.9149, gen loss: -0.6771, gp loss: 0.7947
# validation accuracy: 0.4609
# classification loss: 0.3504, classification acc: 0.9180
# classification loss: 0.3498, classification acc: 0.9201
# critic loss: 0.9208, gen loss: -0.6822, gp loss: 0.7946
# validation accuracy: 0.4661
# classification loss: 0.3432, classification acc: 0.9212
# classification loss: 0.3412, classification acc: 0.9240
# critic loss: 0.9275, gen loss: -0.7071, gp loss: 0.7946
# validation accuracy: 0.4648
# classification loss: 0.3377, classification acc: 0.9219
# classification loss: 0.3354, classification acc: 0.9233
# critic loss: 0.9337, gen loss: -0.7206, gp loss: 0.7947
# validation accuracy: 0.4635
# classification loss: 0.3294, classification acc: 0.9258
# classification loss: 0.3292, classification acc: 0.9244
# critic loss: 0.9405, gen loss: -0.7627, gp loss: 0.7949
# validation accuracy: 0.4557
# classification loss: 0.3237, classification acc: 0.9272
# classification loss: 0.3234, classification acc: 0.9265
# critic loss: 0.9457, gen loss: -0.7843, gp loss: 0.7948
# validation accuracy: 0.4596
# classification loss: 0.3222, classification acc: 0.9247
# classification loss: 0.3189, classification acc: 0.9265
# critic loss: 0.9505, gen loss: -0.8079, gp loss: 0.7949
# validation accuracy: 0.4583
# classification loss: 0.3124, classification acc: 0.9325
# classification loss: 0.3123, classification acc: 0.9311
# critic loss: 0.9555, gen loss: -0.8340, gp loss: 0.7952
# validation accuracy: 0.4505
# classification loss: 0.3072, classification acc: 0.9308
# classification loss: 0.3070, classification acc: 0.9309
# critic loss: 0.9592, gen loss: -0.8529, gp loss: 0.7947
# validation accuracy: 0.4557
# classification loss: 0.3023, classification acc: 0.9325
# classification loss: 0.3018, classification acc: 0.9341
# critic loss: 0.9636, gen loss: -0.8861, gp loss: 0.7950
# validation accuracy: 0.4505
# classification loss: 0.2971, classification acc: 0.9357
# classification loss: 0.2962, classification acc: 0.9343
# critic loss: 0.9678, gen loss: -0.9253, gp loss: 0.7954
# validation accuracy: 0.4518
# classification loss: 0.2909, classification acc: 0.9325
# classification loss: 0.2908, classification acc: 0.9352
# critic loss: 0.9713, gen loss: -0.9517, gp loss: 0.7952
# validation accuracy: 0.4453
# classification loss: 0.2858, classification acc: 0.9396
# classification loss: 0.2840, classification acc: 0.9407
# critic loss: 0.9744, gen loss: -0.9946, gp loss: 0.7957
# validation accuracy: 0.4531
# classification loss: 0.2775, classification acc: 0.9407
# classification loss: 0.2781, classification acc: 0.9393
# critic loss: 0.9775, gen loss: -1.0264, gp loss: 0.7957
# validation accuracy: 0.4518
# classification loss: 0.2758, classification acc: 0.9446
# classification loss: 0.2750, classification acc: 0.9432
# critic loss: 0.9798, gen loss: -1.0590, gp loss: 0.7959
# validation accuracy: 0.4492
# classification loss: 0.2705, classification acc: 0.9403
# classification loss: 0.2690, classification acc: 0.9409
# critic loss: 0.9826, gen loss: -1.1126, gp loss: 0.7960
# validation accuracy: 0.4583
# classification loss: 0.2648, classification acc: 0.9428
# classification loss: 0.2637, classification acc: 0.9451
# critic loss: 0.9845, gen loss: -1.1285, gp loss: 0.7960
# validation accuracy: 0.4544
# classification loss: 0.2601, classification acc: 0.9432
# classification loss: 0.2583, classification acc: 0.9467
# critic loss: 0.9864, gen loss: -1.1691, gp loss: 0.7959
# validation accuracy: 0.4505
# classification loss: 0.2554, classification acc: 0.9460
# classification loss: 0.2555, classification acc: 0.9476
# critic loss: 0.9882, gen loss: -1.2078, gp loss: 0.7963
# validation accuracy: 0.4466
# classification loss: 0.2507, classification acc: 0.9482
# classification loss: 0.2496, classification acc: 0.9473
# critic loss: 0.9901, gen loss: -1.2609, gp loss: 0.7965
# validation accuracy: 0.4531
# classification loss: 0.2460, classification acc: 0.9496
# classification loss: 0.2459, classification acc: 0.9501
# critic loss: 0.9913, gen loss: -1.3148, gp loss: 0.7967
# validation accuracy: 0.4414
# classification loss: 0.2406, classification acc: 0.9506
# classification loss: 0.2396, classification acc: 0.9513
# critic loss: 0.9926, gen loss: -1.3502, gp loss: 0.7966
# validation accuracy: 0.4336
# classification loss: 0.2363, classification acc: 0.9521
# classification loss: 0.2356, classification acc: 0.9528
# critic loss: 0.9941, gen loss: -1.4141, gp loss: 0.7967
# validation accuracy: 0.4466
# classification loss: 0.2311, classification acc: 0.9528
# classification loss: 0.2307, classification acc: 0.9524
# critic loss: 0.9948, gen loss: -1.4946, gp loss: 0.7973
# validation accuracy: 0.4375
# classification loss: 0.2300, classification acc: 0.9535
# classification loss: 0.2286, classification acc: 0.9558
# critic loss: 0.9956, gen loss: -1.5313, gp loss: 0.7974
# validation accuracy: 0.4284
# classification loss: 0.2229, classification acc: 0.9570
# classification loss: 0.2214, classification acc: 0.9576
# critic loss: 0.9963, gen loss: -1.6041, gp loss: 0.7975
# validation accuracy: 0.4349
# classification loss: 0.2212, classification acc: 0.9570
# classification loss: 0.2208, classification acc: 0.9553
# critic loss: 0.9971, gen loss: -1.6786, gp loss: 0.7979
# validation accuracy: 0.4258
# Training complete in 21m 9s
# validation accuracy: 0.4206
# validation accuracy: 0.4219
# validation accuracy: 0.4245
# validation accuracy: 0.4258
# validation accuracy: 0.4258
