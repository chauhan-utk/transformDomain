# %% [markdown]
# Domain Adaptation using WDGRL architecture

# %%
# %set_env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %set_env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=1

# %%
# %matplotlib notebook
from config import domainData
from config import num_classes as NUM_CLASSES
from torchvision import datasets, models, transforms
import yaml
import numpy as np
import matplotlib.pyplot as plt
import pickle as pkl
import logit
from random import shuffle
import math
import utils

# %%
import torch
import torch.nn as nn
import torch.autograd as autograd
import torch.optim as optim
from torch.autograd import Variable

# %%
# src_pkl = domainData['amazon_resnet50']
# tar_pkl = domainData['webcam_resnet50']
src_pkl = "./amazon_alexnet_4096.pkl"
tar_pkl = "./webcam_alexnet_4096.pkl"
# src_pkl = './amazon_4096.yml'
# tar_pkl = './webcam_4096.yml'

# %%
with open(src_pkl, 'rb') as f:
    src_data = pkl.load(f)
with open(tar_pkl, 'rb') as f:
    tar_data = pkl.load(f)

# with open(src_pkl, 'r') as f:
#     source = yaml.load(f)
# with open(tar_pkl, 'r') as f:
#     target = yaml.load(f)

# %% [markdown]
# def batch_generator(data, batch_size, shuffle=True):
#     len_data = len(data['features'])
#     def shuffle_data():
#         nonlocal len_data
#         idx = list(range(len_data))
#         idx = np.random.permutation(idx)
#         t_features = [data['features'][i] for i in idx]
#         t_labels = [data['labels'][i] for i in idx]
#         data['features'] = t_features
#         data['labels'] = t_labels
#     if shuffle:
#         shuffle_data()
#     batch_count = 0
#     while True:
#         if batch_count * batch_size + batch_size >= len_data:
#             batch_count = 0
#             if shuffle:
#                 shuffle_data()
#         start = (int) (batch_count * batch_size)
#         end = (int) (start + batch_size)
#         batch_count += 1
#         yield torch.stack(data['features'][start:end]), np.vstack(src_data['labels'][start:end])

# %%
wd_param = 0.1
gp_param = 10
lr_wd_D = 1e-3
D_train_num = 10

l2_param = 1e-5
lr = 1e-4
batch_size = 64
num_steps = 3200
num_class = 31
n_input = 4096
n_hidden = [2048, 1024, 512, 256]
lr_sch = None

use_gpu = True

# %%
xs, ys = src_data['features'], src_data['labels']
xt, yt = tar_data['features'], tar_data['labels']
ys = ys.squeeze()
yt = yt.squeeze()
# xs = source['train']
# ys = source['train_labels']
# xt = target['train']
# yt = target['train_labels']

# %%
class _Generator(nn.Module):
    def __init__(self, act=nn.ReLU(inplace=True)):
        super(_Generator, self).__init__()
        self.h1 = nn.Sequential(nn.Linear(n_input, n_hidden[0]), act,
                                nn.Linear(n_hidden[0], n_hidden[1]), act,
                                nn.Linear(n_hidden[1], n_hidden[2]), act,
                                nn.Linear(n_hidden[2], n_hidden[3]), act
                                )
        utils.weight_init(self.h1)

    def forward(self, x):
        out = self.h1(x)
        return out

class _Classifier(nn.Module):
    """
    Using nn.CrossEntropyLoss() for tf.nn.softmax_cross_entropy_with_logits()
    There is difference in target labels. This loss requires target labels
    in range [0,C-1] instead of one-hot-encoding, as required in tensorflow.
    Also, CrossEntropyLoss() uses LogSoftmax instead of normal Softmax.
    """
    def __init__(self, act=nn.ReLU(inplace=True)):
        super(_Classifier, self).__init__()
        self.h = nn.Sequential(nn.Linear(n_hidden[-1], 128), act,
                               nn.Linear(128,128), act,
                               nn.Linear(128, 64), act,
                               nn.Linear(64, num_class))
        utils.weight_init(self.h)

    def forward(self, x):
        out = self.h(x)
        return out

class _Critic(nn.Module):
    def __init__(self, act=nn.ReLU(inplace=True)):
        super(_Critic, self).__init__()
        self.h1 = nn.Sequential(nn.Linear(n_hidden[-1], 128), act,
                               nn.Linear(128, 64), act,
                               nn.Linear(64, 1))
        utils.weight_init(self.h1)

    def forward(self, x):
        out = self.h1(x)
        return out

class Model(object):
    def __init__(self):
        self.cr = _Critic()
        self.gen = _Generator()
        self.cls = _Classifier()

# %%
model = Model()
model.cr = model.cr.cuda() if use_gpu else model.cr
model.gen = model.gen.cuda() if use_gpu else model.gen
model.cls = model.cls.cuda() if use_gpu else model.cls

# %%
# cls_criterion = nn.CrossEntropyLoss()
cls_criterion = utils.softmax_cross_entropy_with_logits(num_class)
l2_reg = utils.L2_Loss()
softmax_ = nn.Softmax(dim=1)

params_wd = [
{'params': model.cr.parameters(), 'lr': lr_wd_D}
]
# wd_d_op = optim.SGD(params_wd, momentum=0.9)
wd_d_op = optim.Adam(params_wd)

params = [
{'params': model.gen.parameters(), 'lr': lr},
{'params': model.cls.parameters(), 'lr': lr}
]
# train_op = optim.SGD(params, momentum=0.9)
train_op = optim.Adam(params)
lr_sch = optim.lr_scheduler.ExponentialLR(train_op, 0.1)

# %% [markdown]
# S_batches = batch_generator(src_data, batch_size)
# xs_batch, ys_batch = next(S_batches)

# %%
def test(i, acc):
    XS = torch.from_numpy(xs).float()
    XS = XS.cuda() if use_gpu else XS
    y_true = torch.from_numpy(ys).long()
    y_true = y_true.cuda() if use_gpu else y_true
    
    XS = Variable(XS, volatile=True)
    y_true = Variable(y_true, requires_grad=False)
    
    h2 = model.gen(XS)
    logits = model.cls(h2)
    clf_loss = cls_criterion(logits, y_true)
    logits = softmax_(logits)
    _, pred_idx = torch.max(logits, 1)
    clf_acc = torch.eq(pred_idx, y_true).float().mean()
#     clf_acc = torch.sum(pred_idx == y_true) / y_true.size(0)
    print('step: ', i)
    print('source classifier loss: %f, source accuracy: %f' % (clf_loss, clf_acc))
    acc['src'].append(clf_acc.cpu().data.numpy())

    XS = torch.from_numpy(xt).float()
    XS = XS.cuda() if use_gpu else XS
    y_true = torch.from_numpy(yt).long()
    y_true = y_true.cuda() if use_gpu else y_true
    
    XS = Variable(XS, volatile=True)
    y_true = Variable(y_true, requires_grad=False)
    
    h2 = model.gen(XS)
    logits = model.cls(h2)
    clf_loss = cls_criterion(logits, y_true)
    logits = softmax_(logits)
    _, pred_idx = torch.max(logits, 1)
    clf_acc = torch.eq(pred_idx, y_true).float().mean()
#     clf_acc = torch.sum(pred_idx == y_true) / y_true.size(0)
    print('target classifier loss: %f, target accuracy: %f' % (clf_loss, clf_acc))
#     ax.plot(clf_acc)
    acc['tar'].append(clf_acc.cpu().data.numpy())

# %%
acc = { 'src': [], 'tar': [] }

def train():

    # put all network in training mode
    model.gen.train()
    model.cr.train()
    model.cls.train()

    S_batches = utils.batch_generator([xs, ys], batch_size / 2)
    T_batches = utils.batch_generator([xt, yt], batch_size / 2)

    for i in range(num_steps):
        xs_batch, ys_batch = next(S_batches)
        xt_batch, yt_batch = next(T_batches)
        xb = np.vstack([xs_batch, xt_batch])
        # yb = np.hstack([ys_batch, yt_batch])

        for _ in range(D_train_num):
            wd_d_op.zero_grad()
            XB = torch.from_numpy(xb).float()
            if use_gpu:
                XB = XB.cuda()
            XB = Variable(XB)
            h2 = model.gen(XB)
            h2_s = h2[:batch_size // 2]
            h2_t = h2[batch_size // 2:]

            alpha = torch.Tensor(h2_s.size()).uniform_(0.1,0.9)
            if use_gpu:
                alpha = alpha.cuda()
            difference = h2_s.data - h2_t.data
            interpolates = h2_s.data + (alpha * difference)
#             h2_whole = interpolates

            h2_whole = torch.cat([h2.data, interpolates])

            if use_gpu:
                h2_whole = h2_whole.cuda()
            h2_whole = Variable(h2_whole, requires_grad=True)
            critic_out1 = model.cr(h2)
            critic_out = model.cr(h2_whole)

            critic_s = critic_out1[:batch_size // 2]
#             critic_t = critic_out1[batch_size // 2:]
            critic_t = critic_out[batch_size // 2:batch_size]
            
            wd_loss = torch.sigmoid(critic_t) ** 2 + (1. - torch.sigmoid(critic_s)) ** 2
            wd_loss = wd_loss.mean()

#             wd_loss = critic_s.mean() - critic_t.mean()


            ones = torch.ones(critic_out.size())
            if use_gpu:
                ones = ones.cuda()

            grads = autograd.grad(critic_out, h2_whole, grad_outputs=ones,
                retain_graph=True, create_graph=True, only_inputs=True)[0]

#             slopes = torch.sqrt(torch.sum(grads ** 2, dim=1))
#             gradient_penalty = ((slopes - 1.) ** 2).mean()
            gradient_penalty = ((grads.norm(2, dim=1) - 1) ** 2).mean() 

#             grads = grads.view(grads.size(0), -1)
#             gradient_penalty = ((grads.norm(2, dim=1) - 1.) ** 2).mean()l

            wd_loss_t = wd_loss + gp_param * gradient_penalty
            wd_loss_t.backward()
            wd_d_op.step()

        train_op.zero_grad()        
        XB = torch.from_numpy(xb).float()
        ys_batch = torch.from_numpy(ys_batch).long()
        if use_gpu:
            XB = XB.cuda()
            ys_batch = ys_batch.cuda()
        XB = Variable(XB)
        ys_batch = Variable(ys_batch, requires_grad=False)
        h2 = model.gen(XB)
        h2_s = h2[:batch_size // 2]
        h2_t = h2[batch_size // 2:]

        alpha = torch.Tensor(h2_s.size()).uniform_(0.1,0.9)
        if use_gpu:
            alpha = alpha.cuda()
        difference = h2_s.data - h2_t.data
        interpolates = h2_s.data + (alpha * difference)

        h2_whole = torch.cat([h2.data, interpolates])
        h2_whole = Variable(h2_whole, requires_grad=True)
        
        critic_out = model.cr(h2_whole)
#         critic_out = model.cr(h2)
    
        critic_s = critic_out[:batch_size // 2]
        critic_t = critic_out[batch_size // 2:batch_size]
#         critic_t = critic_out[batch_size // 2:]

        wd_loss = critic_s - critic_t
        if i%200==0:
            wd_loss = -1 * wd_loss
        wd_loss = wd_loss.mean()

        pred_logit = model.cls(h2_s)
        clf_loss = cls_criterion(pred_logit, ys_batch)

        # https://discuss.pytorch.org/t/simple-l2-regularization/139/2
        # https://discuss.pytorch.org/t/add-custom-regularizer-to-loss/4831/2
        l2_loss = None
        for name, param in model.gen.named_parameters():
            if 'weight' in name:
                if l2_loss is None:
                    l2_loss = l2_reg(param) * l2_param
                else:
                    l2_loss += l2_reg(param) * l2_param
        for name, param in model.cr.named_parameters():
            if 'weight' in name:	
                l2_loss += l2_reg(param) * l2_param
                
        P = i / num_steps
#         utils.adjust_learning_rate(train_op, P)
        lmbd = 2. / (1. + math.exp(-10 * P)) - 1.
#         print("new wd_param:", lmbd)
        total_loss = clf_loss + l2_loss + (1. - lmbd) * wd_loss
        # total_loss = clf_loss + wd_param * wd_loss
        total_loss.backward()
        train_op.step()
        
        if i % 500 == 0 and lr_sch is not None:
            lr_sch.step()

        if i % 10 == 0:
            print(lmbd)
            test(i, acc)

# %%
# %time train()
# Out:
# 0.0
# step:  0
# source classifier loss: 4.049394, source accuracy: 0.035144
# target classifier loss: 3.996413, target accuracy: 0.021384
# 0.015623728558408878
# step:  10
# source classifier loss: 3.428989, source accuracy: 0.083777
# target classifier loss: 3.501337, target accuracy: 0.080503
# 0.031239831446031152
# step:  20
# source classifier loss: 3.192865, source accuracy: 0.199858
# target classifier loss: 3.393479, target accuracy: 0.139623
# 0.04684069787264811
# step:  30
# source classifier loss: 2.797700, source accuracy: 0.249911
# target classifier loss: 3.191042, target accuracy: 0.163522
# 0.06241874674751258
# step:  40
# source classifier loss: 2.554735, source accuracy: 0.299255
# target classifier loss: 3.038263, target accuracy: 0.181132
# 0.07796644137536823
# step:  50
# source classifier loss: 2.521787, source accuracy: 0.306354
# target classifier loss: 3.097163, target accuracy: 0.181132
# 0.09347630396922768
# step:  60
# source classifier loss: 2.397920, source accuracy: 0.304224
# target classifier loss: 3.092068, target accuracy: 0.174843
# 0.10894092992085458
# step:  70
# source classifier loss: 2.201773, source accuracy: 0.387291
# target classifier loss: 2.933082, target accuracy: 0.208805
# 0.12435300177159614
# step:  80
# source classifier loss: 2.179211, source accuracy: 0.405396
# target classifier loss: 2.794943, target accuracy: 0.232704
# 0.13970530282831417
# step:  90
# source classifier loss: 1.983641, source accuracy: 0.441605
# target classifier loss: 2.751229, target accuracy: 0.252830
# 0.1549907303716236
# step:  100
# source classifier loss: 1.887651, source accuracy: 0.474618
# target classifier loss: 2.768243, target accuracy: 0.276730
# 0.17020230840646233
# step:  110
# source classifier loss: 2.007437, source accuracy: 0.462194
# target classifier loss: 2.827540, target accuracy: 0.262893
# 0.18533319990813935
# step:  120
# source classifier loss: 1.931216, source accuracy: 0.442315
# target classifier loss: 2.739436, target accuracy: 0.265409
# 0.20037671852040995
# step:  130
# source classifier loss: 2.188317, source accuracy: 0.397231
# target classifier loss: 3.087860, target accuracy: 0.184906
# 0.2153263396657834
# step:  140
# source classifier loss: 1.856873, source accuracy: 0.507277
# target classifier loss: 2.467153, target accuracy: 0.330818
# 0.23017571103213297
# step:  150
# source classifier loss: 1.653407, source accuracy: 0.563720
# target classifier loss: 2.579853, target accuracy: 0.306918
# 0.2449186624037092
# step:  160
# source classifier loss: 1.874544, source accuracy: 0.482428
# target classifier loss: 2.894574, target accuracy: 0.233962
# 0.25954921480882676
# step:  170
# source classifier loss: 1.559372, source accuracy: 0.583245
# target classifier loss: 2.611545, target accuracy: 0.311950
# 0.27406158896076627
# step:  180
# source classifier loss: 1.484391, source accuracy: 0.607739
# target classifier loss: 2.413924, target accuracy: 0.342138
# 0.2884502129727393
# step:  190
# source classifier loss: 1.543367, source accuracy: 0.576855
# target classifier loss: 2.494066, target accuracy: 0.318239
# 0.3027097293321084
# step:  200
# source classifier loss: 1.418345, source accuracy: 0.615903
# target classifier loss: 2.598650, target accuracy: 0.327044
# 0.31683500112336604
# step:  210
# source classifier loss: 1.402557, source accuracy: 0.618388
# target classifier loss: 2.412355, target accuracy: 0.367296
# 0.33082111749362797
# step:  220
# source classifier loss: 1.358508, source accuracy: 0.650337
# target classifier loss: 2.669539, target accuracy: 0.332075
# 0.34466339835857207
# step:  230
# source classifier loss: 1.354389, source accuracy: 0.658147
# target classifier loss: 2.443193, target accuracy: 0.354717
# 0.35835739835078595
# step:  240
# source classifier loss: 1.370917, source accuracy: 0.624423
# target classifier loss: 2.288476, target accuracy: 0.393711
# 0.371898910016385
# step:  250
# source classifier loss: 1.276918, source accuracy: 0.661697
# target classifier loss: 2.344462, target accuracy: 0.371069
# 0.38528396626947226
# step:  260
# source classifier loss: 1.396176, source accuracy: 0.609514
# target classifier loss: 2.470385, target accuracy: 0.325786
# 0.3985088421175169
# step:  270
# source classifier loss: 1.256608, source accuracy: 0.664892
# target classifier loss: 2.577545, target accuracy: 0.359748
# 0.4115700556740225
# step:  280
# source classifier loss: 1.415891, source accuracy: 0.626553
# target classifier loss: 2.565831, target accuracy: 0.328302
# 0.4244643684778939
# step:  290
# source classifier loss: 1.356322, source accuracy: 0.625488
# target classifier loss: 2.314768, target accuracy: 0.376101
# 0.4371887851417122
# step:  300
# source classifier loss: 1.132812, source accuracy: 0.692581
# target classifier loss: 2.378577, target accuracy: 0.388679
# 0.4497405523536495
# step:  310
# source classifier loss: 1.147872, source accuracy: 0.682641
# target classifier loss: 2.417012, target accuracy: 0.361006
# 0.4621171572600098
# step:  320
# source classifier loss: 1.128787, source accuracy: 0.702875
# target classifier loss: 2.527943, target accuracy: 0.347170
# 0.4743163252573668
# step:  330
# source classifier loss: 1.166973, source accuracy: 0.686901
# target classifier loss: 2.231162, target accuracy: 0.396226
# 0.4863360172249622
# step:  340
# source classifier loss: 1.103424, source accuracy: 0.701100
# target classifier loss: 2.286085, target accuracy: 0.401258
# 0.49817442622945496
# step:  350
# source classifier loss: 1.028018, source accuracy: 0.720270
# target classifier loss: 2.288184, target accuracy: 0.406289
# 0.5098299737352565
# step:  360
# source classifier loss: 1.017131, source accuracy: 0.732694
# target classifier loss: 2.281568, target accuracy: 0.407547
# 0.5213013053545767
# step:  370
# source classifier loss: 1.002481, source accuracy: 0.728790
# target classifier loss: 2.271778, target accuracy: 0.427673
# 0.5325872861719194
# step:  380
# source classifier loss: 1.016994, source accuracy: 0.735179
# target classifier loss: 2.257177, target accuracy: 0.417610
# 0.5436869956781494
# step:  390
# source classifier loss: 1.016200, source accuracy: 0.719560
# target classifier loss: 2.487799, target accuracy: 0.359748
# 0.5545997223493822
# step:  400
# source classifier loss: 1.007765, source accuracy: 0.727015
# target classifier loss: 2.282619, target accuracy: 0.406289
# 0.5653249579058752
# step:  410
# source classifier loss: 1.051334, source accuracy: 0.707490
# target classifier loss: 2.354183, target accuracy: 0.388679
# 0.5758623912857894
# step:  420
# source classifier loss: 0.991025, source accuracy: 0.725240
# target classifier loss: 2.124886, target accuracy: 0.449057
# 0.5862119023682237
# step:  430
# source classifier loss: 0.914440, source accuracy: 0.757188
# target classifier loss: 2.214570, target accuracy: 0.389937
# 0.5963735554792424
# step:  440
# source classifier loss: 0.928628, source accuracy: 0.752929
# target classifier loss: 2.049015, target accuracy: 0.462893
# 0.6063475927138031
# step:  450
# source classifier loss: 0.863883, source accuracy: 0.773873
# target classifier loss: 2.298368, target accuracy: 0.403774
# 0.6161344271055265
# step:  460
# source classifier loss: 0.803261, source accuracy: 0.779908
# target classifier loss: 2.104647, target accuracy: 0.450314
# 0.625734635675147
# step:  470
# source classifier loss: 0.823143, source accuracy: 0.786298
# target classifier loss: 2.272307, target accuracy: 0.416352
# 0.6351489523872873
# step:  480
# source classifier loss: 0.856644, source accuracy: 0.775293
# target classifier loss: 2.299778, target accuracy: 0.394969
# 0.6443782610439006
# step:  490
# source classifier loss: 0.909825, source accuracy: 0.760028
# target classifier loss: 2.167648, target accuracy: 0.420126
# 0.6534235881413468
# step:  500
# source classifier loss: 0.867390, source accuracy: 0.768193
# target classifier loss: 2.155306, target accuracy: 0.433962
# 0.6622860957166337
# step:  510
# source classifier loss: 0.772852, source accuracy: 0.793752
# target classifier loss: 2.086161, target accuracy: 0.441509
# 0.6709670742068738
# step:  520
# source classifier loss: 0.727748, source accuracy: 0.813632
# target classifier loss: 2.056013, target accuracy: 0.455346
# 0.6794679353444786
# step:  530
# source classifier loss: 0.698552, source accuracy: 0.819311
# target classifier loss: 2.010239, target accuracy: 0.465409
# 0.6877902051090852
# step:  540
# source classifier loss: 0.677836, source accuracy: 0.824636
# target classifier loss: 2.001309, target accuracy: 0.465409
# 0.6959355167556514
# step:  550
# source classifier loss: 0.665514, source accuracy: 0.830671
# target classifier loss: 2.017829, target accuracy: 0.459119
# 0.7039056039366212
# step:  560
# source classifier loss: 0.651254, source accuracy: 0.832091
# target classifier loss: 2.057248, target accuracy: 0.461635
# 0.7117022939345188
# step:  570
# source classifier loss: 0.641930, source accuracy: 0.833511
# target classifier loss: 2.089514, target accuracy: 0.435220
# 0.7193275010198334
# step:  580
# source classifier loss: 0.636196, source accuracy: 0.832446
# target classifier loss: 2.073282, target accuracy: 0.445283
# 0.7267832199475612
# step:  590
# source classifier loss: 0.621305, source accuracy: 0.839191
# target classifier loss: 2.027400, target accuracy: 0.455346
# 0.7340715196043412
# step:  600
# source classifier loss: 0.616509, source accuracy: 0.841321
# target classifier loss: 2.031158, target accuracy: 0.460377
# 0.7411945368167221
# step:  610
# source classifier loss: 0.612051, source accuracy: 0.841676
# target classifier loss: 2.004561, target accuracy: 0.460377
# 0.7481544703297354
# step:  620
# source classifier loss: 0.605495, source accuracy: 0.846290
# target classifier loss: 2.019961, target accuracy: 0.470440
# 0.7549535749636813
# step:  630
# source classifier loss: 0.596908, source accuracy: 0.848775
# target classifier loss: 2.084397, target accuracy: 0.460377
# 0.7615941559557646
# step:  640
# source classifier loss: 0.588136, source accuracy: 0.854100
# target classifier loss: 2.025526, target accuracy: 0.464151
# 0.7680785634920664
# step:  650
# source classifier loss: 0.596310, source accuracy: 0.844515
# target classifier loss: 1.970248, target accuracy: 0.481761
# 0.7744091874342136
# step:  660
# source classifier loss: 0.579092, source accuracy: 0.853745
# target classifier loss: 2.022645, target accuracy: 0.476730
# 0.7805884522440583
# step:  670
# source classifier loss: 0.574237, source accuracy: 0.855165
# target classifier loss: 2.107047, target accuracy: 0.452830
# 0.7866188121086974
# step:  680
# source classifier loss: 0.567800, source accuracy: 0.860135
# target classifier loss: 2.100616, target accuracy: 0.456604
# 0.7925027462672405
# step:  690
# source classifier loss: 0.563772, source accuracy: 0.857295
# target classifier loss: 2.062236, target accuracy: 0.462893
# 0.7982427545398871
# step:  700
# source classifier loss: 0.556208, source accuracy: 0.860490
# target classifier loss: 2.036344, target accuracy: 0.465409
# 0.80384135305908
# step:  710
# source classifier loss: 0.553943, source accuracy: 0.859425
# target classifier loss: 2.045476, target accuracy: 0.479245
# 0.8093010702017811
# step:  720
# source classifier loss: 0.552093, source accuracy: 0.859425
# target classifier loss: 2.072034, target accuracy: 0.479245
# 0.8146244427212481
# step:  730
# source classifier loss: 0.546329, source accuracy: 0.864395
# target classifier loss: 2.036285, target accuracy: 0.481761
# 0.8198140120760964
# step:  740
# source classifier loss: 0.543129, source accuracy: 0.862265
# target classifier loss: 2.052400, target accuracy: 0.475472
# 0.8248723209538829
# step:  750
# source classifier loss: 0.538131, source accuracy: 0.866170
# target classifier loss: 2.068158, target accuracy: 0.462893
# 0.8298019099859595
# step:  760
# source classifier loss: 0.533636, source accuracy: 0.864040
# target classifier loss: 2.071444, target accuracy: 0.466667
# 0.8346053146499224
# step:  770
# source classifier loss: 0.530974, source accuracy: 0.869010
# target classifier loss: 2.068983, target accuracy: 0.469182
# 0.8392850623555859
# step:  780
# source classifier loss: 0.527469, source accuracy: 0.868300
# target classifier loss: 2.084519, target accuracy: 0.479245
# 0.8438436697100982
# step:  790
# source classifier loss: 0.526007, source accuracy: 0.865105
# target classifier loss: 2.126445, target accuracy: 0.461635
# 0.8482836399575131
# step:  800
# source classifier loss: 0.521572, source accuracy: 0.867590
# target classifier loss: 2.089366, target accuracy: 0.457862
# 0.852607460587903
# step:  810
# source classifier loss: 0.515077, source accuracy: 0.873269
# target classifier loss: 2.091479, target accuracy: 0.471698
# 0.8568176011108952
# step:  820
# source classifier loss: 0.514692, source accuracy: 0.874689
# target classifier loss: 2.059473, target accuracy: 0.477987
# 0.8609165109883439
# step:  830
# source classifier loss: 0.514150, source accuracy: 0.871849
# target classifier loss: 2.051319, target accuracy: 0.472956
# 0.8649066177207418
# step:  840
# source classifier loss: 0.507023, source accuracy: 0.875399
# target classifier loss: 2.065794, target accuracy: 0.476730
# 0.8687903250818612
# step:  850
# source classifier loss: 0.498555, source accuracy: 0.877529
# target classifier loss: 2.100178, target accuracy: 0.475472
# 0.8725700114960693
# step:  860
# source classifier loss: 0.498701, source accuracy: 0.877884
# target classifier loss: 2.074835, target accuracy: 0.471698
# 0.8762480285527146
# step:  870
# source classifier loss: 0.500079, source accuracy: 0.876464
# target classifier loss: 2.108941, target accuracy: 0.461635
# 0.8798266996519848
# step:  880
# source classifier loss: 0.497884, source accuracy: 0.876819
# target classifier loss: 2.110379, target accuracy: 0.464151
# 0.883308318776638
# step:  890
# source classifier loss: 0.489269, source accuracy: 0.877529
# target classifier loss: 2.111386, target accuracy: 0.457862
# 0.8866951493840523
# step:  900
# source classifier loss: 0.489085, source accuracy: 0.875044
# target classifier loss: 2.125257, target accuracy: 0.466667
# 0.8899894234130918
# step:  910
# source classifier loss: 0.485442, source accuracy: 0.876819
# target classifier loss: 2.132997, target accuracy: 0.457862
# 0.8931933404003514
# step:  920
# source classifier loss: 0.480771, source accuracy: 0.881434
# target classifier loss: 2.085168, target accuracy: 0.465409
# 0.8963090667004401
# step:  930
# source classifier loss: 0.474653, source accuracy: 0.884629
# target classifier loss: 2.095623, target accuracy: 0.471698
# 0.8993387348050463
# step:  940
# source classifier loss: 0.476201, source accuracy: 0.883209
# target classifier loss: 2.107886, target accuracy: 0.472956
# 0.9022844427556502
# step:  950
# source classifier loss: 0.471430, source accuracy: 0.887469
# target classifier loss: 2.066469, target accuracy: 0.469182
# 0.9051482536448667
# step:  960
# source classifier loss: 0.467800, source accuracy: 0.888534
# target classifier loss: 2.077751, target accuracy: 0.462893
# 0.9079321952015194
# step:  970
# source classifier loss: 0.466852, source accuracy: 0.889599
# target classifier loss: 2.113486, target accuracy: 0.459119
# 0.9106382594546996
# step:  980
# source classifier loss: 0.467428, source accuracy: 0.886404
# target classifier loss: 2.075688, target accuracy: 0.472956
# 0.9132684024721864
# step:  990
# source classifier loss: 0.458983, source accuracy: 0.890664
# target classifier loss: 2.059323, target accuracy: 0.488050
# 0.9158245441687622
# step:  1000
# source classifier loss: 0.453895, source accuracy: 0.890309
# target classifier loss: 2.104465, target accuracy: 0.464151
# 0.9183085681801013
# step:  1010
# source classifier loss: 0.453059, source accuracy: 0.891729
# target classifier loss: 2.106458, target accuracy: 0.462893
# 0.92072232179806
# step:  1020
# source classifier loss: 0.451889, source accuracy: 0.891729
# target classifier loss: 2.103525, target accuracy: 0.466667
# 0.9230676159633513
# step:  1030
# source classifier loss: 0.450369, source accuracy: 0.892084
# target classifier loss: 2.098486, target accuracy: 0.467925
# 0.9253462253117413
# step:  1040
# source classifier loss: 0.448937, source accuracy: 0.893504
# target classifier loss: 2.098926, target accuracy: 0.470440
# 0.9275598882700506
# step:  1050
# source classifier loss: 0.447594, source accuracy: 0.893859
# target classifier loss: 2.102732, target accuracy: 0.471698
# 0.9297103071984134
# step:  1060
# source classifier loss: 0.446944, source accuracy: 0.892084
# target classifier loss: 2.108503, target accuracy: 0.471698
# 0.9317991485753769
# step:  1070
# source classifier loss: 0.446561, source accuracy: 0.892794
# target classifier loss: 2.112462, target accuracy: 0.471698
# 0.9338280432225916
# step:  1080
# source classifier loss: 0.446045, source accuracy: 0.894569
# target classifier loss: 2.112382, target accuracy: 0.472956
# 0.9357985865659837
# step:  1090
# source classifier loss: 0.445441, source accuracy: 0.893504
# target classifier loss: 2.108705, target accuracy: 0.476730
# 0.9377123389304431
# step:  1100
# source classifier loss: 0.445053, source accuracy: 0.893504
# target classifier loss: 2.109438, target accuracy: 0.475472
# 0.9395708258652122
# step:  1110
# source classifier loss: 0.444572, source accuracy: 0.893859
# target classifier loss: 2.108239, target accuracy: 0.475472
# 0.9413755384972873
# step:  1120
# source classifier loss: 0.443710, source accuracy: 0.894924
# target classifier loss: 2.101396, target accuracy: 0.475472
# 0.9431279339102947
# step:  1130
# source classifier loss: 0.443047, source accuracy: 0.893859
# target classifier loss: 2.091522, target accuracy: 0.477987
# 0.9448294355464197
# step:  1140
# source classifier loss: 0.442524, source accuracy: 0.892794
# target classifier loss: 2.086099, target accuracy: 0.476730
# 0.9464814336291136
# step:  1150
# source classifier loss: 0.442026, source accuracy: 0.894924
# target classifier loss: 2.087669, target accuracy: 0.476730
# 0.9480852856044062
# step:  1160
# source classifier loss: 0.441839, source accuracy: 0.895634
# target classifier loss: 2.089592, target accuracy: 0.477987
# 0.9496423165987962
# step:  1170
# source classifier loss: 0.441394, source accuracy: 0.895279
# target classifier loss: 2.094563, target accuracy: 0.477987
# 0.9511538198917857
# step:  1180
# source classifier loss: 0.441032, source accuracy: 0.895279
# target classifier loss: 2.097795, target accuracy: 0.477987
# 0.9526210574012512
# step:  1190
# source classifier loss: 0.440726, source accuracy: 0.894924
# target classifier loss: 2.101004, target accuracy: 0.480503
# 0.9540452601799487
# step:  1200
# source classifier loss: 0.440146, source accuracy: 0.895634
# target classifier loss: 2.107184, target accuracy: 0.476730
# 0.9554276289215491
# step:  1210
# source classifier loss: 0.439718, source accuracy: 0.896699
# target classifier loss: 2.107204, target accuracy: 0.475472
# 0.9567693344747048
# step:  1220
# source classifier loss: 0.439132, source accuracy: 0.896699
# target classifier loss: 2.100806, target accuracy: 0.476730
# 0.9580715183637447
# step:  1230
# source classifier loss: 0.438574, source accuracy: 0.896699
# target classifier loss: 2.094626, target accuracy: 0.476730
# 0.9593352933146824
# step:  1240
# source classifier loss: 0.438210, source accuracy: 0.897764
# target classifier loss: 2.092849, target accuracy: 0.477987
# 0.9605617437853069
# step:  1250
# source classifier loss: 0.437947, source accuracy: 0.898119
# target classifier loss: 2.091119, target accuracy: 0.481761
# 0.9617519264982224
# step:  1260
# source classifier loss: 0.437745, source accuracy: 0.897409
# target classifier loss: 2.093506, target accuracy: 0.480503
# 0.9629068709757655
# step:  1270
# source classifier loss: 0.437540, source accuracy: 0.897764
# target classifier loss: 2.094515, target accuracy: 0.479245
# 0.9640275800758169
# step:  1280
# source classifier loss: 0.436958, source accuracy: 0.896699
# target classifier loss: 2.094101, target accuracy: 0.480503
# 0.9651150305275895
# step:  1290
# source classifier loss: 0.436377, source accuracy: 0.897409
# target classifier loss: 2.098934, target accuracy: 0.480503
# 0.9661701734665469
# step:  1300
# source classifier loss: 0.435879, source accuracy: 0.898474
# target classifier loss: 2.101782, target accuracy: 0.480503
# 0.9671939349676739
# step:  1310
# source classifier loss: 0.435412, source accuracy: 0.898119
# target classifier loss: 2.102764, target accuracy: 0.476730
# 0.9681872165763705
# step:  1320
# source classifier loss: 0.435079, source accuracy: 0.898119
# target classifier loss: 2.098935, target accuracy: 0.477987
# 0.9691508958363175
# step:  1330
# source classifier loss: 0.434992, source accuracy: 0.898119
# target classifier loss: 2.101380, target accuracy: 0.475472
# 0.9700858268137
# step:  1340
# source classifier loss: 0.434611, source accuracy: 0.898119
# target classifier loss: 2.097108, target accuracy: 0.477987
# 0.9709928406172359
# step:  1350
# source classifier loss: 0.434287, source accuracy: 0.898119
# target classifier loss: 2.098994, target accuracy: 0.476730
# 0.9718727459135088
# step:  1360
# source classifier loss: 0.433804, source accuracy: 0.897764
# target classifier loss: 2.103343, target accuracy: 0.476730
# 0.9727263294371402
# step:  1370
# source classifier loss: 0.433451, source accuracy: 0.898829
# target classifier loss: 2.101928, target accuracy: 0.477987
# 0.9735543564953897
# step:  1380
# source classifier loss: 0.433053, source accuracy: 0.899184
# target classifier loss: 2.095373, target accuracy: 0.479245
# 0.9743575714668116
# step:  1390
# source classifier loss: 0.432787, source accuracy: 0.898119
# target classifier loss: 2.088791, target accuracy: 0.477987
# 0.9751366982936283
# step:  1400
# source classifier loss: 0.432241, source accuracy: 0.898829
# target classifier loss: 2.094815, target accuracy: 0.477987
# 0.9758924409675269
# step:  1410
# source classifier loss: 0.431727, source accuracy: 0.898119
# target classifier loss: 2.097455, target accuracy: 0.477987
# 0.9766254840086113
# step:  1420
# source classifier loss: 0.431508, source accuracy: 0.899894
# target classifier loss: 2.102057, target accuracy: 0.477987
# 0.977336492937277
# step:  1430
# source classifier loss: 0.431666, source accuracy: 0.899539
# target classifier loss: 2.099761, target accuracy: 0.477987
# 0.9780261147388136
# step:  1440
# source classifier loss: 0.431643, source accuracy: 0.899539
# target classifier loss: 2.097759, target accuracy: 0.477987
# 0.9786949783205476
# step:  1450
# source classifier loss: 0.430926, source accuracy: 0.899894
# target classifier loss: 2.097967, target accuracy: 0.476730
# 0.9793436949613898
# step:  1460
# source classifier loss: 0.430378, source accuracy: 0.898474
# target classifier loss: 2.095617, target accuracy: 0.479245
# 0.9799728587536536
# step:  1470
# source classifier loss: 0.429951, source accuracy: 0.898474
# target classifier loss: 2.099339, target accuracy: 0.480503
# 0.9805830470370518
# step:  1480
# source classifier loss: 0.429598, source accuracy: 0.898474
# target classifier loss: 2.103870, target accuracy: 0.477987
# 0.9811748208247801
# step:  1490
# source classifier loss: 0.429283, source accuracy: 0.899539
# target classifier loss: 2.107506, target accuracy: 0.476730
# 0.9817487252216388
# step:  1500
# source classifier loss: 0.428770, source accuracy: 0.899539
# target classifier loss: 2.109087, target accuracy: 0.476730
# 0.9823052898341393
# step:  1510
# source classifier loss: 0.428756, source accuracy: 0.899894
# target classifier loss: 2.109215, target accuracy: 0.476730
# 0.9828450291725761
# step:  1520
# source classifier loss: 0.428723, source accuracy: 0.899539
# target classifier loss: 2.109367, target accuracy: 0.476730
# 0.9833684430450518
# step:  1530
# source classifier loss: 0.428686, source accuracy: 0.899894
# target classifier loss: 2.109585, target accuracy: 0.477987
# 0.9838760169434568
# step:  1540
# source classifier loss: 0.428641, source accuracy: 0.899894
# target classifier loss: 2.109282, target accuracy: 0.477987
# 0.9843682224214227
# step:  1550
# source classifier loss: 0.428590, source accuracy: 0.899894
# target classifier loss: 2.109109, target accuracy: 0.479245
# 0.9848455174642785
# step:  1560
# source classifier loss: 0.428523, source accuracy: 0.899894
# target classifier loss: 2.108821, target accuracy: 0.476730
# 0.9853083468510457
# step:  1570
# source classifier loss: 0.428461, source accuracy: 0.899894
# target classifier loss: 2.108253, target accuracy: 0.475472
# 0.9857571425085299
# step:  1580
# source classifier loss: 0.428397, source accuracy: 0.899894
# target classifier loss: 2.107381, target accuracy: 0.475472
# 0.9861923238575561
# step:  1590
# source classifier loss: 0.428343, source accuracy: 0.899539
# target classifier loss: 2.107203, target accuracy: 0.475472
# 0.9866142981514305
# step:  1600
# source classifier loss: 0.428292, source accuracy: 0.899184
# target classifier loss: 2.106279, target accuracy: 0.475472
# 0.9870234608066868
# step:  1610
# source classifier loss: 0.428230, source accuracy: 0.898829
# target classifier loss: 2.105518, target accuracy: 0.476730
# 0.987420195726215
# step:  1620
# source classifier loss: 0.428182, source accuracy: 0.899184
# target classifier loss: 2.104941, target accuracy: 0.476730
# 0.9878048756148494
# step:  1630
# source classifier loss: 0.428152, source accuracy: 0.899539
# target classifier loss: 2.105201, target accuracy: 0.476730
# 0.9881778622875124
# step:  1640
# source classifier loss: 0.428119, source accuracy: 0.899184
# target classifier loss: 2.105624, target accuracy: 0.476730
# 0.988539506970016
# step:  1650
# source classifier loss: 0.428069, source accuracy: 0.899539
# target classifier loss: 2.105427, target accuracy: 0.477987
# 0.988890150592618
# step:  1660
# source classifier loss: 0.428040, source accuracy: 0.899539
# target classifier loss: 2.105994, target accuracy: 0.477987
# 0.9892301240764443
# step:  1670
# source classifier loss: 0.427996, source accuracy: 0.899539
# target classifier loss: 2.105875, target accuracy: 0.476730
# 0.9895597486128833
# step:  1680
# source classifier loss: 0.427935, source accuracy: 0.899894
# target classifier loss: 2.105392, target accuracy: 0.476730
# 0.9898793359360678
# step:  1690
# source classifier loss: 0.427894, source accuracy: 0.899539
# target classifier loss: 2.104938, target accuracy: 0.476730
# 0.9901891885885559
# step:  1700
# source classifier loss: 0.427854, source accuracy: 0.899894
# target classifier loss: 2.105107, target accuracy: 0.476730
# 0.9904896001803338
# step:  1710
# source classifier loss: 0.427811, source accuracy: 0.900248
# target classifier loss: 2.104776, target accuracy: 0.476730
# 0.9907808556412518
# step:  1720
# source classifier loss: 0.427768, source accuracy: 0.899894
# target classifier loss: 2.104266, target accuracy: 0.476730
# 0.9910632314670178
# step:  1730
# source classifier loss: 0.427735, source accuracy: 0.899894
# target classifier loss: 2.104514, target accuracy: 0.479245
# 0.9913369959588723
# step:  1740
# source classifier loss: 0.427698, source accuracy: 0.900248
# target classifier loss: 2.104600, target accuracy: 0.477987
# 0.9916024094570561
# step:  1750
# source classifier loss: 0.427654, source accuracy: 0.900248
# target classifier loss: 2.104751, target accuracy: 0.477987
# 0.9918597245682079
# step:  1760
# source classifier loss: 0.427604, source accuracy: 0.899894
# target classifier loss: 2.104944, target accuracy: 0.477987
# 0.9921091863867961
# step:  1770
# source classifier loss: 0.427554, source accuracy: 0.899894
# target classifier loss: 2.105107, target accuracy: 0.477987
# 0.9923510327107254
# step:  1780
# source classifier loss: 0.427519, source accuracy: 0.899894
# target classifier loss: 2.105512, target accuracy: 0.477987
# 0.9925854942512276
# step:  1790
# source classifier loss: 0.427478, source accuracy: 0.899894
# target classifier loss: 2.105408, target accuracy: 0.477987
# 0.9928127948371597
# step:  1800
# source classifier loss: 0.427432, source accuracy: 0.900248
# target classifier loss: 2.105319, target accuracy: 0.479245
# 0.9930331516138384
# step:  1810
# source classifier loss: 0.427396, source accuracy: 0.900248
# target classifier loss: 2.105587, target accuracy: 0.479245
# 0.9932467752365213
# step:  1820
# source classifier loss: 0.427355, source accuracy: 0.900248
# target classifier loss: 2.105246, target accuracy: 0.479245
# 0.9934538700586568
# step:  1830
# source classifier loss: 0.427313, source accuracy: 0.899894
# target classifier loss: 2.104814, target accuracy: 0.479245
# 0.9936546343150297
# step:  1840
# source classifier loss: 0.427277, source accuracy: 0.899539
# target classifier loss: 2.104387, target accuracy: 0.479245
# 0.9938492602999036
# step:  1850
# source classifier loss: 0.427241, source accuracy: 0.899539
# target classifier loss: 2.104321, target accuracy: 0.479245
# 0.9940379345402903
# step:  1860
# source classifier loss: 0.427204, source accuracy: 0.899894
# target classifier loss: 2.104136, target accuracy: 0.477987
# 0.9942208379644526
# step:  1870
# source classifier loss: 0.427165, source accuracy: 0.899894
# target classifier loss: 2.103972, target accuracy: 0.479245
# 0.9943981460657578
# step:  1880
# source classifier loss: 0.427117, source accuracy: 0.899894
# target classifier loss: 2.103352, target accuracy: 0.479245
# 0.9945700290619899
# step:  1890
# source classifier loss: 0.427078, source accuracy: 0.899894
# target classifier loss: 2.103611, target accuracy: 0.479245
# 0.994736652050231
# step:  1900
# source classifier loss: 0.427050, source accuracy: 0.899894
# target classifier loss: 2.104360, target accuracy: 0.479245
# 0.9948981751574268
# step:  1910
# source classifier loss: 0.427018, source accuracy: 0.899894
# target classifier loss: 2.104826, target accuracy: 0.479245
# 0.9950547536867307
# step:  1920
# source classifier loss: 0.426974, source accuracy: 0.899894
# target classifier loss: 2.104673, target accuracy: 0.479245
# 0.9952065382597419
# step:  1930
# source classifier loss: 0.426928, source accuracy: 0.899539
# target classifier loss: 2.104318, target accuracy: 0.479245
# 0.9953536749547376
# step:  1940
# source classifier loss: 0.426884, source accuracy: 0.899539
# target classifier loss: 2.104125, target accuracy: 0.479245
# 0.995496305440994
# step:  1950
# source classifier loss: 0.426847, source accuracy: 0.899894
# target classifier loss: 2.104321, target accuracy: 0.479245
# 0.9956345671093094
# step:  1960
# source classifier loss: 0.426813, source accuracy: 0.899894
# target classifier loss: 2.103740, target accuracy: 0.479245
# 0.9957685931988136
# step:  1970
# source classifier loss: 0.426776, source accuracy: 0.899894
# target classifier loss: 2.103677, target accuracy: 0.479245
# 0.9958985129201652
# step:  1980
# source classifier loss: 0.426738, source accuracy: 0.899894
# target classifier loss: 2.103777, target accuracy: 0.479245
# 0.9960244515752319
# step:  1990
# source classifier loss: 0.426705, source accuracy: 0.899894
# target classifier loss: 2.104013, target accuracy: 0.479245
# 0.996146530673345
# step:  2000
# source classifier loss: 0.426657, source accuracy: 0.899894
# target classifier loss: 2.103492, target accuracy: 0.479245
# 0.9962648680442134
# step:  2010
# source classifier loss: 0.426652, source accuracy: 0.899894
# target classifier loss: 2.103468, target accuracy: 0.479245
# 0.9963795779475948
# step:  2020
# source classifier loss: 0.426648, source accuracy: 0.899894
# target classifier loss: 2.103464, target accuracy: 0.479245
# 0.9964907711798012
# step:  2030
# source classifier loss: 0.426643, source accuracy: 0.899894
# target classifier loss: 2.103462, target accuracy: 0.479245
# 0.9965985551771297
# step:  2040
# source classifier loss: 0.426640, source accuracy: 0.899894
# target classifier loss: 2.103467, target accuracy: 0.479245
# 0.9967030341162972
# step:  2050
# source classifier loss: 0.426636, source accuracy: 0.899894
# target classifier loss: 2.103507, target accuracy: 0.479245
# 0.9968043090119654
# step:  2060
# source classifier loss: 0.426632, source accuracy: 0.899894
# target classifier loss: 2.103572, target accuracy: 0.479245
# 0.9969024778114239
# step:  2070
# source classifier loss: 0.426628, source accuracy: 0.899894
# target classifier loss: 2.103578, target accuracy: 0.479245
# 0.996997635486526
# step:  2080
# source classifier loss: 0.426624, source accuracy: 0.899894
# target classifier loss: 2.103559, target accuracy: 0.479245
# 0.9970898741229344
# step:  2090
# source classifier loss: 0.426620, source accuracy: 0.899894
# target classifier loss: 2.103565, target accuracy: 0.479245
# 0.9971792830067638
# step:  2100
# source classifier loss: 0.426617, source accuracy: 0.899894
# target classifier loss: 2.103546, target accuracy: 0.479245
# 0.9972659487086875
# step:  2110
# source classifier loss: 0.426613, source accuracy: 0.899894
# target classifier loss: 2.103510, target accuracy: 0.479245
# 0.9973499551655736
# step:  2120
# source classifier loss: 0.426609, source accuracy: 0.899894
# target classifier loss: 2.103482, target accuracy: 0.479245
# 0.9974313837597322
# step:  2130
# source classifier loss: 0.426605, source accuracy: 0.899894
# target classifier loss: 2.103429, target accuracy: 0.479245
# 0.9975103133958232
# step:  2140
# source classifier loss: 0.426601, source accuracy: 0.899894
# target classifier loss: 2.103394, target accuracy: 0.479245
# 0.9975868205755074
# step:  2150
# source classifier loss: 0.426596, source accuracy: 0.899894
# target classifier loss: 2.103388, target accuracy: 0.479245
# 0.997660979469889
# step:  2160
# source classifier loss: 0.426592, source accuracy: 0.899894
# target classifier loss: 2.103381, target accuracy: 0.479245
# 0.9977328619898251
# step:  2170
# source classifier loss: 0.426589, source accuracy: 0.899894
# target classifier loss: 2.103382, target accuracy: 0.479245
# 0.9978025378541506
# step:  2180
# source classifier loss: 0.426586, source accuracy: 0.899894
# target classifier loss: 2.103415, target accuracy: 0.479245
# 0.9978700746558882
# step:  2190
# source classifier loss: 0.426582, source accuracy: 0.899894
# target classifier loss: 2.103448, target accuracy: 0.479245
# 0.9979355379264905
# step:  2200
# source classifier loss: 0.426578, source accuracy: 0.899894
# target classifier loss: 2.103462, target accuracy: 0.479245
# 0.9979989911981799
# step:  2210
# source classifier loss: 0.426575, source accuracy: 0.899894
# target classifier loss: 2.103516, target accuracy: 0.479245
# 0.9980604960644348
# step:  2220
# source classifier loss: 0.426571, source accuracy: 0.899894
# target classifier loss: 2.103539, target accuracy: 0.479245
# 0.9981201122386745
# step:  2230
# source classifier loss: 0.426567, source accuracy: 0.899539
# target classifier loss: 2.103590, target accuracy: 0.479245
# 0.9981778976111988
# step:  2240
# source classifier loss: 0.426563, source accuracy: 0.899539
# target classifier loss: 2.103630, target accuracy: 0.479245
# 0.9982339083044309
# step:  2250
# source classifier loss: 0.426559, source accuracy: 0.899539
# target classifier loss: 2.103655, target accuracy: 0.479245
# 0.9982881987265098
# step:  2260
# source classifier loss: 0.426556, source accuracy: 0.899894
# target classifier loss: 2.103639, target accuracy: 0.479245
# 0.9983408216232819
# step:  2270
# source classifier loss: 0.426552, source accuracy: 0.899894
# target classifier loss: 2.103643, target accuracy: 0.479245
# 0.9983918281287416
# step:  2280
# source classifier loss: 0.426549, source accuracy: 0.899894
# target classifier loss: 2.103629, target accuracy: 0.479245
# 0.9984412678139583
# step:  2290
# source classifier loss: 0.426544, source accuracy: 0.899894
# target classifier loss: 2.103559, target accuracy: 0.479245
# 0.9984891887345411
# step:  2300
# source classifier loss: 0.426540, source accuracy: 0.899894
# target classifier loss: 2.103522, target accuracy: 0.479245
# 0.9985356374766783
# step:  2310
# source classifier loss: 0.426537, source accuracy: 0.899894
# target classifier loss: 2.103466, target accuracy: 0.479245
# 0.998580659201799
# step:  2320
# source classifier loss: 0.426533, source accuracy: 0.899894
# target classifier loss: 2.103435, target accuracy: 0.479245
# 0.9986242976898896
# step:  2330
# source classifier loss: 0.426529, source accuracy: 0.899894
# target classifier loss: 2.103454, target accuracy: 0.479245
# 0.998666595381513
# step:  2340
# source classifier loss: 0.426526, source accuracy: 0.899894
# target classifier loss: 2.103464, target accuracy: 0.479245
# 0.9987075934185607
# step:  2350
# source classifier loss: 0.426522, source accuracy: 0.899894
# target classifier loss: 2.103476, target accuracy: 0.479245
# 0.9987473316837809
# step:  2360
# source classifier loss: 0.426518, source accuracy: 0.899894
# target classifier loss: 2.103481, target accuracy: 0.479245
# 0.998785848839117
# step:  2370
# source classifier loss: 0.426513, source accuracy: 0.899894
# target classifier loss: 2.103493, target accuracy: 0.479245
# 0.9988231823628861
# step:  2380
# source classifier loss: 0.426509, source accuracy: 0.899894
# target classifier loss: 2.103495, target accuracy: 0.479245
# 0.9988593685858431
# step:  2390
# source classifier loss: 0.426505, source accuracy: 0.899894
# target classifier loss: 2.103488, target accuracy: 0.479245
# 0.9988944427261528
# step:  2400
# source classifier loss: 0.426501, source accuracy: 0.899894
# target classifier loss: 2.103497, target accuracy: 0.479245
# 0.9989284389233053
# step:  2410
# source classifier loss: 0.426497, source accuracy: 0.899894
# target classifier loss: 2.103497, target accuracy: 0.479245
# 0.9989613902710099
# step:  2420
# source classifier loss: 0.426493, source accuracy: 0.899894
# target classifier loss: 2.103481, target accuracy: 0.479245
# 0.9989933288490944
# step:  2430
# source classifier loss: 0.426489, source accuracy: 0.899894
# target classifier loss: 2.103544, target accuracy: 0.479245
# 0.9990242857544356
# step:  2440
# source classifier loss: 0.426484, source accuracy: 0.899894
# target classifier loss: 2.103494, target accuracy: 0.479245
# 0.9990542911309594
# step:  2450
# source classifier loss: 0.426480, source accuracy: 0.899894
# target classifier loss: 2.103461, target accuracy: 0.479245
# 0.99908337419873
# step:  2460
# source classifier loss: 0.426476, source accuracy: 0.899894
# target classifier loss: 2.103475, target accuracy: 0.479245
# 0.999111563282157
# step:  2470
# source classifier loss: 0.426473, source accuracy: 0.899894
# target classifier loss: 2.103514, target accuracy: 0.479245
# 0.9991388858373509
# step:  2480
# source classifier loss: 0.426469, source accuracy: 0.899894
# target classifier loss: 2.103627, target accuracy: 0.479245
# 0.9991653684786446
# step:  2490
# source classifier loss: 0.426465, source accuracy: 0.899894
# target classifier loss: 2.103650, target accuracy: 0.479245
# 0.9991910370043158
# step:  2500
# source classifier loss: 0.426461, source accuracy: 0.899894
# target classifier loss: 2.103565, target accuracy: 0.479245
# 0.9992159164215246
# step:  2510
# source classifier loss: 0.426461, source accuracy: 0.899894
# target classifier loss: 2.103561, target accuracy: 0.479245
# 0.9992400309704961
# step:  2520
# source classifier loss: 0.426460, source accuracy: 0.899894
# target classifier loss: 2.103560, target accuracy: 0.479245
# 0.999263404147968
# step:  2530
# source classifier loss: 0.426460, source accuracy: 0.899894
# target classifier loss: 2.103562, target accuracy: 0.479245
# 0.9992860587299246
# step:  2540
# source classifier loss: 0.426460, source accuracy: 0.899894
# target classifier loss: 2.103561, target accuracy: 0.479245
# 0.9993080167936437
# step:  2550
# source classifier loss: 0.426460, source accuracy: 0.899894
# target classifier loss: 2.103560, target accuracy: 0.479245
# 0.9993292997390673
# step:  2560
# source classifier loss: 0.426460, source accuracy: 0.899894
# target classifier loss: 2.103560, target accuracy: 0.479245
# 0.9993499283095266
# step:  2570
# source classifier loss: 0.426460, source accuracy: 0.899894
# target classifier loss: 2.103558, target accuracy: 0.479245
# 0.9993699226118375
# step:  2580
# source classifier loss: 0.426460, source accuracy: 0.899894
# target classifier loss: 2.103561, target accuracy: 0.479245
# 0.999389302135776
# step:  2590
# source classifier loss: 0.426460, source accuracy: 0.899894
# target classifier loss: 2.103561, target accuracy: 0.479245
# 0.9994080857729739
# step:  2600
# source classifier loss: 0.426459, source accuracy: 0.899894
# target classifier loss: 2.103562, target accuracy: 0.479245
# 0.999426291835225
# step:  2610
# source classifier loss: 0.426459, source accuracy: 0.899894
# target classifier loss: 2.103563, target accuracy: 0.479245
# 0.9994439380722449
# step:  2620
# source classifier loss: 0.426459, source accuracy: 0.899894
# target classifier loss: 2.103564, target accuracy: 0.479245
# 0.9994610416888825
# step:  2630
# source classifier loss: 0.426459, source accuracy: 0.899894
# target classifier loss: 2.103563, target accuracy: 0.479245
# 0.9994776193618087
# step:  2640
# source classifier loss: 0.426459, source accuracy: 0.899894
# target classifier loss: 2.103562, target accuracy: 0.479245
# 0.9994936872556979
# step:  2650
# source classifier loss: 0.426459, source accuracy: 0.899894
# target classifier loss: 2.103561, target accuracy: 0.479245
# 0.9995092610389145
# step:  2660
# source classifier loss: 0.426459, source accuracy: 0.899894
# target classifier loss: 2.103561, target accuracy: 0.479245
# 0.9995243558987195
# step:  2670
# source classifier loss: 0.426459, source accuracy: 0.899894
# target classifier loss: 2.103561, target accuracy: 0.479245
# 0.9995389865560136
# step:  2680
# source classifier loss: 0.426458, source accuracy: 0.899894
# target classifier loss: 2.103560, target accuracy: 0.479245
# 0.9995531672796345
# step:  2690
# source classifier loss: 0.426458, source accuracy: 0.899894
# target classifier loss: 2.103560, target accuracy: 0.479245
# 0.9995669119002097
# step:  2700
# source classifier loss: 0.426458, source accuracy: 0.899894
# target classifier loss: 2.103559, target accuracy: 0.479245
# 0.9995802338235937
# step:  2710
# source classifier loss: 0.426458, source accuracy: 0.899894
# target classifier loss: 2.103561, target accuracy: 0.479245
# 0.9995931460438896
# step:  2720
# source classifier loss: 0.426458, source accuracy: 0.899894
# target classifier loss: 2.103562, target accuracy: 0.479245
# 0.9996056611560755
# step:  2730
# source classifier loss: 0.426458, source accuracy: 0.899894
# target classifier loss: 2.103561, target accuracy: 0.479245
# 0.9996177913682447
# step:  2740
# source classifier loss: 0.426458, source accuracy: 0.899894
# target classifier loss: 2.103560, target accuracy: 0.479245
# 0.9996295485134694
# step:  2750
# source classifier loss: 0.426457, source accuracy: 0.899894
# target classifier loss: 2.103560, target accuracy: 0.479245
# 0.9996409440613065
# step:  2760
# source classifier loss: 0.426457, source accuracy: 0.899894
# target classifier loss: 2.103560, target accuracy: 0.479245
# 0.9996519891289457
# step:  2770
# source classifier loss: 0.426457, source accuracy: 0.899894
# target classifier loss: 2.103558, target accuracy: 0.479245
# 0.9996626944920217
# step:  2780
# source classifier loss: 0.426457, source accuracy: 0.899894
# target classifier loss: 2.103558, target accuracy: 0.479245
# 0.9996730705950918
# step:  2790
# source classifier loss: 0.426457, source accuracy: 0.899894
# target classifier loss: 2.103558, target accuracy: 0.479245
# 0.999683127561795
# step:  2800
# source classifier loss: 0.426457, source accuracy: 0.899894
# target classifier loss: 2.103560, target accuracy: 0.479245
# 0.9996928752047007
# step:  2810
# source classifier loss: 0.426457, source accuracy: 0.899894
# target classifier loss: 2.103560, target accuracy: 0.479245
# 0.9997023230348541
# step:  2820
# source classifier loss: 0.426457, source accuracy: 0.899894
# target classifier loss: 2.103560, target accuracy: 0.479245
# 0.9997114802710303
# step:  2830
# source classifier loss: 0.426456, source accuracy: 0.899894
# target classifier loss: 2.103559, target accuracy: 0.479245
# 0.9997203558487056
# step:  2840
# source classifier loss: 0.426456, source accuracy: 0.899894
# target classifier loss: 2.103556, target accuracy: 0.479245
# 0.9997289584287516
# step:  2850
# source classifier loss: 0.426456, source accuracy: 0.899894
# target classifier loss: 2.103557, target accuracy: 0.479245
# 0.9997372964058695
# step:  2860
# source classifier loss: 0.426456, source accuracy: 0.899894
# target classifier loss: 2.103557, target accuracy: 0.479245
# 0.9997453779167558
# step:  2870
# source classifier loss: 0.426456, source accuracy: 0.899894
# target classifier loss: 2.103556, target accuracy: 0.479245
# 0.9997532108480274
# step:  2880
# source classifier loss: 0.426456, source accuracy: 0.899894
# target classifier loss: 2.103557, target accuracy: 0.479245
# 0.9997608028438996
# step:  2890
# source classifier loss: 0.426456, source accuracy: 0.899894
# target classifier loss: 2.103558, target accuracy: 0.479245
# 0.9997681613136271
# step:  2900
# source classifier loss: 0.426455, source accuracy: 0.899894
# target classifier loss: 2.103557, target accuracy: 0.479245
# 0.9997752934387225
# step:  2910
# source classifier loss: 0.426455, source accuracy: 0.899894
# target classifier loss: 2.103559, target accuracy: 0.479245
# 0.9997822061799468
# step:  2920
# source classifier loss: 0.426455, source accuracy: 0.899894
# target classifier loss: 2.103560, target accuracy: 0.479245
# 0.9997889062840914
# step:  2930
# source classifier loss: 0.426455, source accuracy: 0.899894
# target classifier loss: 2.103561, target accuracy: 0.479245
# 0.9997954002905483
# step:  2940
# source classifier loss: 0.426455, source accuracy: 0.899894
# target classifier loss: 2.103561, target accuracy: 0.479245
# 0.9998016945376818
# step:  2950
# source classifier loss: 0.426455, source accuracy: 0.899894
# target classifier loss: 2.103562, target accuracy: 0.479245
# 0.999807795169001
# step:  2960
# source classifier loss: 0.426455, source accuracy: 0.899894
# target classifier loss: 2.103560, target accuracy: 0.479245
# 0.9998137081391485
# step:  2970
# source classifier loss: 0.426455, source accuracy: 0.899894
# target classifier loss: 2.103560, target accuracy: 0.479245
# 0.9998194392196993
# step:  2980
# source classifier loss: 0.426454, source accuracy: 0.899894
# target classifier loss: 2.103560, target accuracy: 0.479245
# 0.9998249940047867
# step:  2990
# source classifier loss: 0.426454, source accuracy: 0.899894
# target classifier loss: 2.103559, target accuracy: 0.479245
# 0.9998303779165529
# step:  3000
# source classifier loss: 0.426454, source accuracy: 0.899894
# target classifier loss: 2.103559, target accuracy: 0.479245
# 0.9998355962104328
# step:  3010
# source classifier loss: 0.426454, source accuracy: 0.899894
# target classifier loss: 2.103559, target accuracy: 0.479245
# 0.9998406539802782
# step:  3020
# source classifier loss: 0.426454, source accuracy: 0.899894
# target classifier loss: 2.103559, target accuracy: 0.479245
# 0.9998455561633188
# step:  3030
# source classifier loss: 0.426454, source accuracy: 0.899894
# target classifier loss: 2.103559, target accuracy: 0.479245
# 0.999850307544979
# step:  3040
# source classifier loss: 0.426454, source accuracy: 0.899894
# target classifier loss: 2.103559, target accuracy: 0.479245
# 0.9998549127635394
# step:  3050
# source classifier loss: 0.426454, source accuracy: 0.899894
# target classifier loss: 2.103559, target accuracy: 0.479245
# 0.9998593763146617
# step:  3060
# source classifier loss: 0.426454, source accuracy: 0.899894
# target classifier loss: 2.103559, target accuracy: 0.479245
# 0.9998637025557675
# step:  3070
# source classifier loss: 0.426454, source accuracy: 0.899894
# target classifier loss: 2.103559, target accuracy: 0.479245
# 0.9998678957102909
# step:  3080
# source classifier loss: 0.426454, source accuracy: 0.899894
# target classifier loss: 2.103559, target accuracy: 0.479245
# 0.9998719598717924
# step:  3090
# source classifier loss: 0.426454, source accuracy: 0.899894
# target classifier loss: 2.103559, target accuracy: 0.479245
# 0.9998758990079541
# step:  3100
# source classifier loss: 0.426454, source accuracy: 0.899894
# target classifier loss: 2.103559, target accuracy: 0.479245
# 0.9998797169644462
# step:  3110
# source classifier loss: 0.426454, source accuracy: 0.899894
# target classifier loss: 2.103559, target accuracy: 0.479245
# 0.9998834174686777
# step:  3120
# source classifier loss: 0.426454, source accuracy: 0.899894
# target classifier loss: 2.103559, target accuracy: 0.479245
# 0.9998870041334327
# step:  3130
# source classifier loss: 0.426454, source accuracy: 0.899894
# target classifier loss: 2.103559, target accuracy: 0.479245
# 0.999890480460391
# step:  3140
# source classifier loss: 0.426454, source accuracy: 0.899894
# target classifier loss: 2.103559, target accuracy: 0.479245
# 0.9998938498435468
# step:  3150
# source classifier loss: 0.426454, source accuracy: 0.899894
# target classifier loss: 2.103559, target accuracy: 0.479245
# 0.9998971155725158
# step:  3160
# source classifier loss: 0.426454, source accuracy: 0.899894
# target classifier loss: 2.103559, target accuracy: 0.479245
# 0.9999002808357453
# step:  3170
# source classifier loss: 0.426454, source accuracy: 0.899894
# target classifier loss: 2.103559, target accuracy: 0.479245
# 0.9999033487236255
# step:  3180
# source classifier loss: 0.426454, source accuracy: 0.899894
# target classifier loss: 2.103559, target accuracy: 0.479245
# 0.9999063222315012
# step:  3190
# source classifier loss: 0.426454, source accuracy: 0.899894
# target classifier loss: 2.103559, target accuracy: 0.479245
# CPU times: user 3min 18s, sys: 26.8 s, total: 3min 44s
# Wall time: 3min 46s

# %% [markdown]
# fig = plt.figure()
# ax1 = fig.add_subplot(211)
# fig.subplots_adjust(bottom=0.2)
# line1 = ax1.plot(acc['src'],'b',label='Source Accuracy')
# line2 = ax1.plot(acc['tar'],'g',label='Target Accuracy')
# ax1.set_ylim(0,1)
# lines = line1+line2
# labels = [l.get_label() for l in lines]
# ax1.legend(lines, labels, loc=(0,-0.4), ncol=2)
# plt.show()
