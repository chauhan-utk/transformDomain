# %% [markdown]
# Domain Adaptation using WDGRL architecture

# %%
# %set_env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %set_env CUDA_VISIBLE_DEVICES=3
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=3

# %%
from config import domainData
from config import num_classes as NUM_CLASSES
from torchvision import datasets, models, transforms
import yaml
import numpy as np
import pickle as pkl
import logit
from random import shuffle
import utils

# %%
import torch
import torch.nn as nn
import torch.autograd as autograd
import torch.optim as optim
from torch.autograd import Variable

# %%
# src_pkl = domainData['amazon_resnet50']
# tar_pkl = domainData['webcam_resnet50']
src_pkl = "./amazon_alexnet_4096.pkl"
tar_pkl = "./webcam_alexnet_4096.pkl"
# src_pkl = './amazon_4096.yml'
# tar_pkl = './webcam_4096.yml'

# %%
with open(src_pkl, 'rb') as f:
    src_data = pkl.load(f)
with open(tar_pkl, 'rb') as f:
    tar_data = pkl.load(f)

# with open(src_pkl, 'r') as f:
#     source = yaml.load(f)
# with open(tar_pkl, 'r') as f:
#     target = yaml.load(f)

# %% [markdown]
# def batch_generator(data, batch_size, shuffle=True):
#     len_data = len(data['features'])
#     def shuffle_data():
#         nonlocal len_data
#         idx = list(range(len_data))
#         idx = np.random.permutation(idx)
#         t_features = [data['features'][i] for i in idx]
#         t_labels = [data['labels'][i] for i in idx]
#         data['features'] = t_features
#         data['labels'] = t_labels
#     if shuffle:
#         shuffle_data()
#     batch_count = 0
#     while True:
#         if batch_count * batch_size + batch_size >= len_data:
#             batch_count = 0
#             if shuffle:
#                 shuffle_data()
#         start = (int) (batch_count * batch_size)
#         end = (int) (start + batch_size)
#         batch_count += 1
#         yield torch.stack(data['features'][start:end]), np.vstack(src_data['labels'][start:end])

# %%
wd_param = 0.1
gp_param = 10
lr_wd_D = 1e-3
D_train_num = 10

l2_param = 1e-5
lr = 1e-4
batch_size = 64
num_steps = 1200
num_class = 31
n_input = 4096
n_hidden = [500, 100]

use_gpu = False

# %%
xs, ys = src_data['features'], src_data['labels']
xt, yt = tar_data['features'], tar_data['labels']
ys = ys.squeeze()
yt = yt.squeeze()
# xs = source['train']
# ys = source['train_labels']
# xt = target['train']
# yt = target['train_labels']

# %%
class _Generator(nn.Module):
    def __init__(self, act=nn.ReLU(inplace=True)):
        super(_Generator, self).__init__()
        self.h1 = nn.Sequential(nn.Linear(n_input, n_hidden[0]), act)
        self.h2 = nn.Sequential(nn.Linear(n_hidden[0], n_hidden[1]), act)
        utils.weight_init(self.h1)
        utils.weight_init(self.h2)
# 		for x in self.h1.modules():
# 			utils.weight_init(x)
# 		for x in self.h2.modules():
# 			utils.weight_init(x)

    def forward(self, x):
        x = self.h1(x)
        out = self.h2(x)
        return out

class _Classifier(nn.Module):
    """
    Using nn.CrossEntropyLoss() for tf.nn.softmax_cross_entropy_with_logits()
    There is difference in target labels. This loss requires target labels
    in range [0,C-1] instead of one-hot-encoding, as required in tensorflow.
    Also, CrossEntropyLoss() uses LogSoftmax instead of normal Softmax.
    """
    def __init__(self):
        super(_Classifier, self).__init__()
        self.h = nn.Linear(n_hidden[-1], num_class)
        utils.weight_init(self.h)
#         for x in self.h.modules():
#             utils.weight_init(x)

    def forward(self, x):
        out = self.h(x)
        return out

class _Critic(nn.Module):
    def __init__(self, act=nn.ReLU(inplace=True)):
        super(_Critic, self).__init__()
        self.h1 = nn.Sequential(nn.Linear(n_hidden[-1], 100), act)
        self.out = nn.Linear(100, 1)
        utils.weight_init(self.h1)
        utils.weight_init(self.out)
# 		for x in self.h1.modules():
# 			utils.weight_init(x)
# 		for x in self.out.modules():
# 			utils.weight_init(x)

    def forward(self, x):
        x = self.h1(x)
        out = self.out(x)
        return out

class Model(object):
    def __init__(self):
        self.cr = _Critic()
        self.gen = _Generator()
        self.cls = _Classifier()

# %%
model = Model()

# %%
# cls_criterion = nn.CrossEntropyLoss()
cls_criterion = utils.softmax_cross_entropy_with_logits(num_class)
l2_reg = utils.L2_Loss()
softmax_ = nn.Softmax(dim=1)

params_wd = [
{'params': model.cr.parameters(), 'lr': lr_wd_D}
]
wd_d_op = optim.Adam(params_wd)

params = [
{'params': model.gen.parameters()},
{'params': model.cls.parameters()}
]
train_op = optim.Adam(params, lr=lr)

# %% [markdown]
# S_batches = batch_generator(src_data, batch_size)
# xs_batch, ys_batch = next(S_batches)

# %%
def test(i=0):
    XS = Variable(torch.from_numpy(xs).float(), volatile=True)
    y_true = Variable(torch.from_numpy(ys).long(), requires_grad=False)
    h2 = model.gen(XS)
    logits = model.cls(h2)
    clf_loss = cls_criterion(logits, y_true)
    logits = softmax_(logits)
    _, pred_idx = torch.max(logits, 1)
    clf_acc = torch.eq(pred_idx, y_true).float().mean()
#     clf_acc = torch.sum(pred_idx == y_true) / y_true.size(0)
    print('step: ', i)
    print('source classifier loss: %f, source accuracy: %f' % (clf_loss, clf_acc))

    XS = Variable(torch.from_numpy(xt).float(), volatile=True)
    y_true = Variable(torch.from_numpy(yt).long(), requires_grad=False)
    h2 = model.gen(XS)
    logits = model.cls(h2)
    clf_loss = cls_criterion(logits, y_true)
    logits = softmax_(logits)
    _, pred_idx = torch.max(logits, 1)
    clf_acc = torch.eq(pred_idx, y_true).float().mean()
#     clf_acc = torch.sum(pred_idx == y_true) / y_true.size(0)
    print('target classifier loss: %f, target accuracy: %f' % (clf_loss, clf_acc))

# %%
def train():

    # put all network in training mode
    model.gen.train()
    model.cr.train()
    model.cls.train()

    S_batches = utils.batch_generator([xs, ys], batch_size / 2)
    T_batches = utils.batch_generator([xt, yt], batch_size / 2)

    for i in range(num_steps):
        xs_batch, ys_batch = next(S_batches)
        xt_batch, yt_batch = next(T_batches)
        xb = np.vstack([xs_batch, xt_batch])
        # yb = np.hstack([ys_batch, yt_batch])

        for _ in range(D_train_num):
            wd_d_op.zero_grad()
            XB = torch.from_numpy(xb).float()
            if use_gpu:
                XB = XB.cuda()
            XB = Variable(XB)
            h2 = model.gen(XB)
            h2_s = h2[:batch_size // 2]
            h2_t = h2[batch_size // 2:]

            alpha = torch.Tensor(h2_s.size()).uniform_(0,1)
            if use_gpu:
                alpha = alpha.cuda()
            difference = h2_s.data - h2_t.data
            interpolates = h2_s.data + (alpha * difference)

            h2_whole = torch.cat([h2.data, interpolates])

            if use_gpu:
                h2_whole = h2_whole.cuda()
            h2_whole = Variable(h2_whole, requires_grad=True)
            critic_out = model.cr(h2_whole)

            critic_s = critic_out[:batch_size // 2]
            critic_t = critic_out[batch_size // 2:batch_size]
            
            wd_loss = torch.sigmoid(critic_t) ** 2 + (1. - torch.sigmoid(critic_s)) ** 2
            wd_loss = wd_loss.mean()

#             wd_loss = critic_s.mean() - critic_t.mean()


            ones = torch.ones(critic_out.size())
            if use_gpu:
                ones = ones.cuda()

            grads = autograd.grad(critic_out, h2_whole, grad_outputs=ones,
                retain_graph=True, create_graph=True)[0]

            slopes = torch.sqrt(torch.sum(grads ** 2, dim=1))
            gradient_penalty = ((slopes - 1.) ** 2).mean()

#             grads = grads.view(grads.size(0), -1)
#             gradient_penalty = ((grads.norm(2, dim=1) - 1.) ** 2).mean()

            wd_loss_t = wd_loss + gp_param * gradient_penalty
            wd_loss_t.backward()
            wd_d_op.step()

        train_op.zero_grad()
        utils.adjust
        XB = torch.from_numpy(xb).float()
        ys_batch = torch.from_numpy(ys_batch).long()
        if use_gpu:
            XB = XB.cuda()
            ys_batch = ys_batch.cuda()
        XB = Variable(XB)
        ys_batch = Variable(ys_batch, requires_grad=False)
        h2 = model.gen(XB)
        h2_s = h2[:batch_size // 2]
        h2_t = h2[batch_size // 2:]

        alpha = torch.Tensor(h2_s.size()).uniform_(0,1)
        if use_gpu:
            alpha = alpha.cuda()
        difference = h2_s.data - h2_t.data
        interpolates = h2_s.data + (alpha * difference)

        h2_whole = torch.cat([h2.data, interpolates])
        h2_whole = Variable(h2_whole, requires_grad=True)
        
        critic_out = model.cr(h2_whole)

        critic_s = critic_out[:batch_size // 2]
        critic_t = critic_out[batch_size // 2:batch_size]

        wd_loss = critic_s - critic_t
        wd_loss = wd_loss.mean()

        pred_logit = model.cls(h2_s)
        clf_loss = cls_criterion(pred_logit, ys_batch)

        # https://discuss.pytorch.org/t/simple-l2-regularization/139/2
        # https://discuss.pytorch.org/t/add-custom-regularizer-to-loss/4831/2
        l2_loss = None
        # l2_loss = torch.Tensor(1).zero_()
        # if use_gpu:
        # 	l2_loss = l2_loss.cuda()
        # l2_loss = Variable(l2_loss, requires_grad=True)
        for name, param in model.gen.named_parameters():
#             print(name, param, type(param))
            if 'weight' in name:
                if l2_loss is None:
                    l2_loss = l2_reg(param) * l2_param
                else:
                    l2_loss += l2_reg(param) * l2_param
        for name, param in model.cr.named_parameters():
            if 'weight' in name:	
                l2_loss += l2_reg(param) * l2_param

#         print("wd_loss: ", wd_loss)
        total_loss = clf_loss + l2_loss + wd_param * wd_loss
        # total_loss = clf_loss + wd_param * wd_loss
        total_loss.backward()
        train_op.step()

        if i % 10 == 0:
            test(i)

# %%
train()
# Out:
# step:  0
# source classifier loss: 13.927851, source accuracy: 0.056088
# target classifier loss: 11.250607, target accuracy: 0.037736
# step:  10
# source classifier loss: 6.940927, source accuracy: 0.091232
# target classifier loss: 6.737860, target accuracy: 0.067925
# step:  20
# source classifier loss: 3.505122, source accuracy: 0.197728
# target classifier loss: 3.917571, target accuracy: 0.096855
# step:  30
# source classifier loss: 2.958606, source accuracy: 0.217962
# target classifier loss: 3.555614, target accuracy: 0.130818
# step:  40
# source classifier loss: 2.700550, source accuracy: 0.298900
# target classifier loss: 3.533226, target accuracy: 0.133333
# step:  50
# source classifier loss: 2.426571, source accuracy: 0.349308
# target classifier loss: 3.116075, target accuracy: 0.181132
# step:  60
# source classifier loss: 2.294974, source accuracy: 0.401846
# target classifier loss: 3.204958, target accuracy: 0.194969
# step:  70
# source classifier loss: 2.160150, source accuracy: 0.413561
# target classifier loss: 2.908835, target accuracy: 0.220126
# step:  80
# source classifier loss: 2.158031, source accuracy: 0.433085
# target classifier loss: 3.244629, target accuracy: 0.223899
# step:  90
# source classifier loss: 1.898239, source accuracy: 0.486688
# target classifier loss: 2.919083, target accuracy: 0.233962
# step:  100
# source classifier loss: 1.804935, source accuracy: 0.516507
# target classifier loss: 2.863037, target accuracy: 0.251572
# step:  110
# source classifier loss: 1.718598, source accuracy: 0.531416
# target classifier loss: 2.797660, target accuracy: 0.274214
# step:  120
# source classifier loss: 1.706667, source accuracy: 0.540291
# target classifier loss: 2.896111, target accuracy: 0.261635
# step:  130
# source classifier loss: 1.764470, source accuracy: 0.545616
# target classifier loss: 3.071009, target accuracy: 0.251572
# step:  140
# source classifier loss: 1.661649, source accuracy: 0.565495
# target classifier loss: 2.884272, target accuracy: 0.280503
# step:  150
# source classifier loss: 1.713310, source accuracy: 0.533191
# target classifier loss: 2.912617, target accuracy: 0.289308
# step:  160
# source classifier loss: 1.653135, source accuracy: 0.562655
# target classifier loss: 2.832433, target accuracy: 0.275472
# step:  170
# source classifier loss: 1.517880, source accuracy: 0.588214
# target classifier loss: 2.799064, target accuracy: 0.298113
# step:  180
# source classifier loss: 1.396443, source accuracy: 0.624068
# target classifier loss: 2.843462, target accuracy: 0.272956
# step:  190
# source classifier loss: 1.483674, source accuracy: 0.593894
# target classifier loss: 2.822676, target accuracy: 0.294340
# step:  200
# source classifier loss: 1.472633, source accuracy: 0.602769
# target classifier loss: 2.907309, target accuracy: 0.299371
# step:  210
# source classifier loss: 1.359816, source accuracy: 0.627973
# target classifier loss: 2.832120, target accuracy: 0.294340
# step:  220
# source classifier loss: 1.363026, source accuracy: 0.636493
# target classifier loss: 2.974556, target accuracy: 0.265409
# step:  230
# source classifier loss: 1.446860, source accuracy: 0.612354
# target classifier loss: 2.908060, target accuracy: 0.299371
# step:  240
# source classifier loss: 1.270806, source accuracy: 0.654242
# target classifier loss: 2.855574, target accuracy: 0.300629
# step:  250
# source classifier loss: 1.224648, source accuracy: 0.665247
# target classifier loss: 2.601759, target accuracy: 0.358491
# step:  260
# source classifier loss: 1.097046, source accuracy: 0.707845
# target classifier loss: 2.764055, target accuracy: 0.322013
# step:  270
# source classifier loss: 1.166124, source accuracy: 0.678026
# target classifier loss: 2.769907, target accuracy: 0.322013
# step:  280
# source classifier loss: 1.098316, source accuracy: 0.704295
# target classifier loss: 2.642668, target accuracy: 0.343396
# step:  290
# source classifier loss: 1.040900, source accuracy: 0.711750
# target classifier loss: 2.738803, target accuracy: 0.329560
# step:  300
# source classifier loss: 1.028758, source accuracy: 0.727370
# target classifier loss: 2.830409, target accuracy: 0.340881
# step:  310
# source classifier loss: 1.032401, source accuracy: 0.709265
# target classifier loss: 2.675905, target accuracy: 0.329560
# step:  320
# source classifier loss: 1.117295, source accuracy: 0.690806
# target classifier loss: 2.727554, target accuracy: 0.327044
# step:  330
# source classifier loss: 0.928018, source accuracy: 0.758253
# target classifier loss: 2.728666, target accuracy: 0.316981
# step:  340
# source classifier loss: 0.957671, source accuracy: 0.730209
# target classifier loss: 2.726428, target accuracy: 0.330818
# step:  350
# source classifier loss: 1.014375, source accuracy: 0.718495
# target classifier loss: 2.845425, target accuracy: 0.311950
# step:  360
# source classifier loss: 0.887715, source accuracy: 0.762868
# target classifier loss: 2.777684, target accuracy: 0.329560
# step:  370
# source classifier loss: 0.884234, source accuracy: 0.755769
# target classifier loss: 2.663818, target accuracy: 0.328302
# step:  380
# source classifier loss: 0.917092, source accuracy: 0.748669
# target classifier loss: 2.774414, target accuracy: 0.327044
# step:  390
# source classifier loss: 0.960387, source accuracy: 0.721335
# target classifier loss: 2.691596, target accuracy: 0.303145
# step:  400
# source classifier loss: 0.929786, source accuracy: 0.750444
# target classifier loss: 2.953487, target accuracy: 0.296855
# step:  410
# source classifier loss: 0.880205, source accuracy: 0.747959
# target classifier loss: 2.674182, target accuracy: 0.363522
# step:  420
# source classifier loss: 0.857236, source accuracy: 0.749024
# target classifier loss: 2.684320, target accuracy: 0.355975
# step:  430
# source classifier loss: 0.836487, source accuracy: 0.763933
# target classifier loss: 2.601664, target accuracy: 0.349686
# step:  440
# source classifier loss: 0.806364, source accuracy: 0.771033
# target classifier loss: 2.564327, target accuracy: 0.366038
# step:  450
# source classifier loss: 0.776286, source accuracy: 0.782393
# target classifier loss: 2.860644, target accuracy: 0.348428
# step:  460
# source classifier loss: 0.840780, source accuracy: 0.765708
# target classifier loss: 2.645120, target accuracy: 0.340881
# step:  470
# source classifier loss: 0.778155, source accuracy: 0.777068
# target classifier loss: 2.700773, target accuracy: 0.333333
# step:  480
# source classifier loss: 0.810119, source accuracy: 0.765708
# target classifier loss: 2.686061, target accuracy: 0.352201
# step:  490
# source classifier loss: 0.719339, source accuracy: 0.807242
# target classifier loss: 2.731368, target accuracy: 0.342138
# step:  500
# source classifier loss: 0.735812, source accuracy: 0.792332
# target classifier loss: 2.823152, target accuracy: 0.337107
# step:  510
# source classifier loss: 0.699945, source accuracy: 0.806887
# target classifier loss: 2.595026, target accuracy: 0.391195
# step:  520
# source classifier loss: 0.651668, source accuracy: 0.809017
# target classifier loss: 2.518612, target accuracy: 0.392453
# step:  530
# source classifier loss: 0.625296, source accuracy: 0.829961
# target classifier loss: 2.674172, target accuracy: 0.372327
# step:  540
# source classifier loss: 0.612878, source accuracy: 0.828541
# target classifier loss: 2.722849, target accuracy: 0.386164
# step:  550
# source classifier loss: 0.619595, source accuracy: 0.825346
# target classifier loss: 2.705016, target accuracy: 0.373585
# step:  560
# source classifier loss: 0.655319, source accuracy: 0.808662
# target classifier loss: 2.632401, target accuracy: 0.403774
# step:  570
# source classifier loss: 0.631321, source accuracy: 0.816471
# target classifier loss: 2.565033, target accuracy: 0.381132
# step:  580
# source classifier loss: 0.624578, source accuracy: 0.820731
# target classifier loss: 2.786541, target accuracy: 0.361006
# step:  590
# source classifier loss: 0.643561, source accuracy: 0.811857
# target classifier loss: 2.637253, target accuracy: 0.374843
# step:  600
# source classifier loss: 0.587670, source accuracy: 0.838126
# target classifier loss: 2.664364, target accuracy: 0.366038
# step:  610
# source classifier loss: 0.651919, source accuracy: 0.812567
# target classifier loss: 2.679674, target accuracy: 0.349686
# step:  620
# source classifier loss: 0.542292, source accuracy: 0.850905
# target classifier loss: 2.725605, target accuracy: 0.369811
# step:  630
# source classifier loss: 0.535122, source accuracy: 0.848775
# target classifier loss: 2.566674, target accuracy: 0.406289
# step:  640
# source classifier loss: 0.510184, source accuracy: 0.853390
# target classifier loss: 2.621575, target accuracy: 0.361006
# step:  650
# source classifier loss: 0.544891, source accuracy: 0.848065
# target classifier loss: 2.762738, target accuracy: 0.358491
# step:  660
# source classifier loss: 0.568942, source accuracy: 0.840256
# target classifier loss: 2.825892, target accuracy: 0.348428
# step:  670
# source classifier loss: 0.573215, source accuracy: 0.828186
# target classifier loss: 2.687329, target accuracy: 0.369811
# step:  680
# source classifier loss: 0.530244, source accuracy: 0.855165
# target classifier loss: 2.622560, target accuracy: 0.382390
# step:  690
# source classifier loss: 0.518750, source accuracy: 0.850195
# target classifier loss: 2.758844, target accuracy: 0.367296
# step:  700
# source classifier loss: 0.540509, source accuracy: 0.852325
# target classifier loss: 2.862090, target accuracy: 0.350943
# step:  710
# source classifier loss: 0.558947, source accuracy: 0.840256
# target classifier loss: 2.753559, target accuracy: 0.361006
# step:  720
# source classifier loss: 0.522425, source accuracy: 0.851970
# target classifier loss: 2.827595, target accuracy: 0.367296
# step:  730
# source classifier loss: 0.441366, source accuracy: 0.875754
# target classifier loss: 2.743719, target accuracy: 0.376101
# step:  740
# source classifier loss: 0.509155, source accuracy: 0.852325
# target classifier loss: 2.717386, target accuracy: 0.374843
# step:  750
# source classifier loss: 0.544342, source accuracy: 0.843450
# target classifier loss: 2.889124, target accuracy: 0.305660
# step:  760
# source classifier loss: 0.471929, source accuracy: 0.870075
# target classifier loss: 2.647666, target accuracy: 0.398742
# step:  770
# source classifier loss: 0.491280, source accuracy: 0.863685
# target classifier loss: 2.834882, target accuracy: 0.363522
# step:  780
# source classifier loss: 0.591536, source accuracy: 0.819666
# target classifier loss: 2.995018, target accuracy: 0.348428
# step:  790
# source classifier loss: 0.539968, source accuracy: 0.836706
# target classifier loss: 2.654840, target accuracy: 0.376101
# step:  800
# source classifier loss: 0.517406, source accuracy: 0.854100
# target classifier loss: 2.507827, target accuracy: 0.392453
# step:  810
# source classifier loss: 0.485860, source accuracy: 0.858005
# target classifier loss: 2.778726, target accuracy: 0.384906
# step:  820
# source classifier loss: 0.433383, source accuracy: 0.880014
# target classifier loss: 2.710909, target accuracy: 0.355975
# step:  830
# source classifier loss: 0.436966, source accuracy: 0.882144
# target classifier loss: 2.756612, target accuracy: 0.369811
# step:  840
# source classifier loss: 0.375932, source accuracy: 0.893149
# target classifier loss: 2.741860, target accuracy: 0.355975
# step:  850
# source classifier loss: 0.391238, source accuracy: 0.895989
# target classifier loss: 2.567542, target accuracy: 0.392453
# step:  860
# source classifier loss: 0.357837, source accuracy: 0.915158
# target classifier loss: 2.698383, target accuracy: 0.378616
# step:  870
# source classifier loss: 0.416245, source accuracy: 0.878239
# target classifier loss: 2.751248, target accuracy: 0.371069
# step:  880
# source classifier loss: 0.372951, source accuracy: 0.896699
# target classifier loss: 2.581120, target accuracy: 0.418868
# step:  890
# source classifier loss: 0.377933, source accuracy: 0.898829
# target classifier loss: 2.659025, target accuracy: 0.377358
# step:  900
# source classifier loss: 0.417890, source accuracy: 0.872204
# target classifier loss: 2.887894, target accuracy: 0.362264
# step:  910
# source classifier loss: 0.348031, source accuracy: 0.904508
# target classifier loss: 2.529910, target accuracy: 0.416352
# step:  920
# source classifier loss: 0.345827, source accuracy: 0.906638
# target classifier loss: 2.721506, target accuracy: 0.412579
# step:  930
# source classifier loss: 0.372036, source accuracy: 0.899539
# target classifier loss: 2.715254, target accuracy: 0.394969
# step:  940
# source classifier loss: 0.339010, source accuracy: 0.905218
# target classifier loss: 2.770755, target accuracy: 0.374843
# step:  950
# source classifier loss: 0.319431, source accuracy: 0.914448
# target classifier loss: 2.768223, target accuracy: 0.383648
# step:  960
# source classifier loss: 0.368679, source accuracy: 0.894214
# target classifier loss: 2.754078, target accuracy: 0.379874
# step:  970
# source classifier loss: 0.371337, source accuracy: 0.890309
# target classifier loss: 2.732364, target accuracy: 0.374843
# step:  980
# source classifier loss: 0.325650, source accuracy: 0.914448
# target classifier loss: 2.593698, target accuracy: 0.420126
# step:  990
# source classifier loss: 0.346142, source accuracy: 0.897409
# target classifier loss: 2.705997, target accuracy: 0.374843
# step:  1000
# source classifier loss: 0.329111, source accuracy: 0.908768
# target classifier loss: 2.684231, target accuracy: 0.386164
# step:  1010
# source classifier loss: 0.304132, source accuracy: 0.913738
# target classifier loss: 2.773803, target accuracy: 0.354717
# step:  1020
# source classifier loss: 0.303990, source accuracy: 0.916223
# target classifier loss: 2.861325, target accuracy: 0.369811
# step:  1030
# source classifier loss: 0.264794, source accuracy: 0.928648
# target classifier loss: 2.671505, target accuracy: 0.388679
# step:  1040
# source classifier loss: 0.305851, source accuracy: 0.913738
# target classifier loss: 2.812321, target accuracy: 0.391195
# step:  1050
# source classifier loss: 0.302170, source accuracy: 0.913738
# target classifier loss: 2.733653, target accuracy: 0.372327
# step:  1060
# source classifier loss: 0.278544, source accuracy: 0.927938
# target classifier loss: 2.765322, target accuracy: 0.386164
# step:  1070
# source classifier loss: 0.263719, source accuracy: 0.933262
# target classifier loss: 2.572233, target accuracy: 0.412579
# step:  1080
# source classifier loss: 0.264410, source accuracy: 0.927583
# target classifier loss: 2.793537, target accuracy: 0.350943
# step:  1090
# source classifier loss: 0.262901, source accuracy: 0.928648
# target classifier loss: 2.784228, target accuracy: 0.379874
# step:  1100
# source classifier loss: 0.293432, source accuracy: 0.918708
# target classifier loss: 2.656106, target accuracy: 0.374843
# step:  1110
# source classifier loss: 0.304541, source accuracy: 0.916578
# target classifier loss: 2.729693, target accuracy: 0.378616
# step:  1120
# source classifier loss: 0.263227, source accuracy: 0.929357
# target classifier loss: 2.747850, target accuracy: 0.384906
# step:  1130
# source classifier loss: 0.263434, source accuracy: 0.926873
# target classifier loss: 2.573511, target accuracy: 0.410063
# step:  1140
# source classifier loss: 0.227800, source accuracy: 0.942137
# target classifier loss: 2.621067, target accuracy: 0.416352
# step:  1150
# source classifier loss: 0.239327, source accuracy: 0.935037
# target classifier loss: 2.784440, target accuracy: 0.362264
# step:  1160
# source classifier loss: 0.224040, source accuracy: 0.941427
# target classifier loss: 2.704565, target accuracy: 0.388679
# step:  1170
# source classifier loss: 0.184041, source accuracy: 0.957756
# target classifier loss: 2.658221, target accuracy: 0.410063
# step:  1180
# source classifier loss: 0.184110, source accuracy: 0.953142
# target classifier loss: 2.629702, target accuracy: 0.403774
# step:  1190
# source classifier loss: 0.177329, source accuracy: 0.962726
# target classifier loss: 2.739808, target accuracy: 0.401258
